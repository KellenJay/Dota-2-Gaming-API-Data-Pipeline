# %% [markdown]
# **Importing libraries**

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# **Pulling Matches Data**

# %%
# Base URLs for the OpenDota API
BASE_URL = "https://api.opendota.com/api"
PUBLIC_MATCHES_URL = f"{BASE_URL}/publicMatches"
MATCH_DETAIL_URL = f"{BASE_URL}/matches/{{match_id}}"

# Function to fetch batches of public matches
def get_public_matches(num_batches=2, delay=1):
    """
    Pulls batches of public matches from OpenDota API.
    num_batches: number of batches to fetch (each batch fetches 50 matches)
    delay: delay in seconds between requests (to avoid hitting rate limits)
    """
    matches = []
    for i in range(num_batches):
        response = requests.get(PUBLIC_MATCHES_URL)
        if response.status_code == 200:
            data = response.json()
            matches.extend(data)
        else:
            print(f"Error fetching matches: {response.status_code}")
        time.sleep(delay)  # Avoid hitting the rate limit
    return matches

# Function to fetch detailed match data (including player statistics)
def get_match_details(match_ids, delay=1):
    """
    Fetches detailed match data for the given match IDs from OpenDota API.
    """
    all_details = []
    for match_id in match_ids:
        url = MATCH_DETAIL_URL.format(match_id=match_id)
        response = requests.get(url)
        if response.status_code == 200:
            match_data = response.json()
            # Flatten player data for each match
            for player in match_data.get("players", []):
                all_details.append({
                    "match_id": match_id,
                    "start_time": match_data.get("start_time"),
                    "duration": match_data.get("duration"),
                    "radiant_win": match_data.get("radiant_win"),
                    "player_slot": player.get("player_slot"),
                    "account_id": player.get("account_id"),
                    "hero_id": player.get("hero_id"),
                    "kills": player.get("kills"),
                    "deaths": player.get("deaths"),
                    "assists": player.get("assists"),
                    "gold_per_min": player.get("gold_per_min"),
                    "xp_per_min": player.get("xp_per_min"),
                    "last_hits": player.get("last_hits"),
                    "denies": player.get("denies"),
                    "gold": player.get("gold"),
                    "hero_damage": player.get("hero_damage"),
                    "hero_healing": player.get("hero_healing")
                })
        else:
            print(f"Error fetching match {match_id}: {response.status_code}")
        time.sleep(delay)  # Avoid hitting the rate limit
    return all_details

# ---- Main Execution ----
if __name__ == "__main__":
    print("Fetching public matches...")
    # Fetch 3 batches (150 matches)
    public_matches = get_public_matches(num_batches=3)  
    match_ids = [m["match_id"] for m in public_matches]

    print("Fetching detailed match data...")
    match_details = get_match_details(match_ids)

    # Convert the data to a pandas DataFrame
    df = pd.DataFrame(match_details)

    # Save the data to a CSV file
    csv_path = r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches.csv" 
    df.to_csv(csv_path, index=False)
    print(f"Saved {len(df)} rows to {csv_path}")
# Out:
# Fetching public matches...
# Fetching detailed match data...
# Error fetching match 8390471517: 500
# Saved 2990 rows to C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches.csv

# %% [markdown]
# **Re-pulling data(handling errors)**

# %%
# Base URLs for the OpenDota API
BASE_URL = "https://api.opendota.com/api"
PUBLIC_MATCHES_URL = f"{BASE_URL}/publicMatches"
MATCH_DETAIL_URL = f"{BASE_URL}/matches/{{match_id}}"

# Function to fetch batches of public matches
def get_public_matches(num_batches=2, delay=1):
    """
    Pulls batches of public matches from OpenDota API.
    num_batches: number of batches to fetch (each batch fetches 50 matches)
    delay: delay in seconds between requests (to avoid hitting rate limits)
    """
    matches = []
    for i in range(num_batches):
        response = requests.get(PUBLIC_MATCHES_URL)
        if response.status_code == 200:
            data = response.json()
            matches.extend(data)
        else:
            print(f"Error fetching matches: {response.status_code}")
        time.sleep(delay)  # Avoid hitting the rate limit
    return matches

# Function to fetch detailed match data (including player statistics)
def get_match_details(match_ids, delay=1):
    """
    Fetches detailed match data for the given match IDs from OpenDota API.
    Skips any matches that return an error (status code 500).
    """
    all_details = []
    for match_id in match_ids:
        url = MATCH_DETAIL_URL.format(match_id=match_id)
        response = requests.get(url)
        if response.status_code == 200:
            match_data = response.json()
            # Flatten player data for each match
            for player in match_data.get("players", []):
                all_details.append({
                    "match_id": match_id,
                    "start_time": match_data.get("start_time"),
                    "duration": match_data.get("duration"),
                    "radiant_win": match_data.get("radiant_win"),
                    "player_slot": player.get("player_slot"),
                    "account_id": player.get("account_id"),
                    "hero_id": player.get("hero_id"),
                    "kills": player.get("kills"),
                    "deaths": player.get("deaths"),
                    "assists": player.get("assists"),
                    "gold_per_min": player.get("gold_per_min"),
                    "xp_per_min": player.get("xp_per_min"),
                    "last_hits": player.get("last_hits"),
                    "denies": player.get("denies"),
                    "gold": player.get("gold"),
                    "hero_damage": player.get("hero_damage"),
                    "hero_healing": player.get("hero_healing")
                })
        elif response.status_code == 500:
            print(f"Error fetching match {match_id}: Internal Server Error (500). Skipping this match.")
        else:
            print(f"Error fetching match {match_id}: Status code {response.status_code}. Skipping this match.")
        time.sleep(delay)  # Avoid hitting the rate limit
    return all_details

# ---- Main Execution ----
if __name__ == "__main__":
    print("Fetching public matches...")
    # Fetch 3 batches (150 matches)
    public_matches = get_public_matches(num_batches=3)  
    match_ids = [m["match_id"] for m in public_matches]

    print("Fetching detailed match data...")
    match_details = get_match_details(match_ids)

    # Convert the data to a pandas DataFrame
    df = pd.DataFrame(match_details)

    # Save the data to a CSV file
    csv_path = r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches.csv"  
    df.to_csv(csv_path, index=False)
    print(f"Saved {len(df)} rows to {csv_path}")
# Out:
# Fetching public matches...
# Fetching detailed match data...
# Error fetching match 8390491615: Internal Server Error (500). Skipping this match.
# Error fetching match 8390495200: Status code 429. Skipping this match.
# Error fetching match 8390495105: Status code 429. Skipping this match.
# Error fetching match 8390495014: Status code 429. Skipping this match.
# Error fetching match 8390495012: Status code 429. Skipping this match.
# Error fetching match 8390494505: Status code 429. Skipping this match.
# Error fetching match 8390494417: Status code 429. Skipping this match.
# Error fetching match 8390494413: Status code 429. Skipping this match.
# Error fetching match 8390494411: Status code 429. Skipping this match.
# Error fetching match 8390494410: Status code 429. Skipping this match.
# Error fetching match 8390494409: Status code 429. Skipping this match.
# Error fetching match 8390494402: Status code 429. Skipping this match.
# Error fetching match 8390494400: Status code 429. Skipping this match.
# Error fetching match 8390494118: Status code 429. Skipping this match.
# Error fetching match 8390494106: Status code 429. Skipping this match.
# Error fetching match 8390494010: Status code 429. Skipping this match.
# Saved 2840 rows to C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches.csv

# %% [markdown]
# **Pulling player data for 40 players**

# %%
import requests
import pandas as pd
import time

# Base URL for OpenDota API
BASE_URL = "https://api.opendota.com/api"
PLAYER_MATCHES_URL = f"{BASE_URL}/players/{{account_id}}/matches"

# Your sampled player IDs (already included)
sampled_players = [
    103356886, 88596567, 146532881, 307648521, 29366434, 109362160,
    200135497, 171627276, 103138418, 125774566, 104482314, 127763760,
    175184565, 152883119, 105081622, 91444156, 107386895, 116905783,
    156159900, 103231619, 130747907, 103980011, 110417858, 103226608,
    108304393, 125108963, 146227106, 127499210, 87014496, 182008047,
    139204898, 104496653, 126831383, 88522209, 111654271, 103432006,
    111377393, 121074870, 101423931, 124203827
]

def fetch_player_matches(account_id, num_matches=20, delay=1):
    """
    Fetches recent matches for a player by account_id.
    Handles 429 rate limit errors by waiting and retrying.
    """
    url = PLAYER_MATCHES_URL.format(account_id=account_id)
    params = {"limit": num_matches}
    response = requests.get(url, params=params)
    
    # Handle rate limiting (429)
    if response.status_code == 429:
        retry_after = int(response.headers.get('Retry-After', 60))
        print(f"Rate limit hit for {account_id}. Retrying after {retry_after} seconds...")
        time.sleep(retry_after)
        response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching matches for player {account_id}: {response.status_code}")
        return []

# ---- Main Execution ----
all_player_matches = []

print("Fetching player match data...")
for account_id in sampled_players:
    matches = fetch_player_matches(account_id, num_matches=20)
    for match in matches:
        all_player_matches.append({
            "account_id": account_id,
            "match_id": match.get("match_id"),
            "hero_id": match.get("hero_id"),
            "kills": match.get("kills"),
            "deaths": match.get("deaths"),
            "assists": match.get("assists"),
            "gold_per_min": match.get("gold_per_min"),
            "xp_per_min": match.get("xp_per_min"),
            "duration": match.get("duration"),
            "radiant_win": match.get("radiant_win"),
            "start_time": match.get("start_time")
        })
    time.sleep(1)  # Delay between players

# Convert to DataFrame
df_players = pd.DataFrame(all_player_matches)

# Save to CSV
csv_path = r"C:\Users\Ellen\Desktop\OpenDota Data\player_match_data.csv"
df_players.to_csv(csv_path, index=False)
print(f"Saved {len(df_players)} rows to {csv_path}")
# Out:
# Fetching player match data...
# Saved 0 rows to C:\Users\Ellen\Desktop\OpenDota Data\player_match_data.csv

# %%
# Base URL for OpenDota API
BASE_URL = "https://api.opendota.com/api"
PLAYER_MATCHES_URL = f"{BASE_URL}/players/{{account_id}}/matches"

# Your sampled player IDs (already included)
sampled_players = [
    103356886, 88596567, 146532881, 307648521, 29366434, 109362160,
    200135497, 171627276, 103138418, 125774566, 104482314, 127763760,
    175184565, 152883119, 105081622, 91444156, 107386895, 116905783,
    156159900, 103231619, 130747907, 103980011, 110417858, 103226608,
    108304393, 125108963, 146227106, 127499210, 87014496, 182008047,
    139204898, 104496653, 126831383, 88522209, 111654271, 103432006,
    111377393, 121074870, 101423931, 124203827
]

def fetch_player_matches(account_id, num_matches=20):
    """
    Fetches recent matches for a player by account_id.
    Handles 429 rate limit errors by waiting and retrying.
    """
    url = PLAYER_MATCHES_URL.format(account_id=account_id)
    params = {"limit": num_matches}
    response = requests.get(url, params=params)
    
    # Handle rate limiting (429)
    if response.status_code == 429:
        retry_after = int(response.headers.get('Retry-After', 60))
        print(f"Rate limit hit for {account_id}. Retrying after {retry_after} seconds...")
        time.sleep(retry_after)
        response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching matches for player {account_id}: {response.status_code}")
        return []

# ---- Main Execution ----
all_player_matches = []

print("Fetching player match data...")
for i, account_id in enumerate(sampled_players, start=1):
    print(f"Fetching data for player {i} of {len(sampled_players)} (account_id={account_id})...")
    matches = fetch_player_matches(account_id, num_matches=20)
    for match in matches:
        all_player_matches.append({
            "account_id": account_id,
            "match_id": match.get("match_id"),
            "hero_id": match.get("hero_id"),
            "kills": match.get("kills"),
            "deaths": match.get("deaths"),
            "assists": match.get("assists"),
            "gold_per_min": match.get("gold_per_min"),
            "xp_per_min": match.get("xp_per_min"),
            "duration": match.get("duration"),
            "radiant_win": match.get("radiant_win"),
            "start_time": match.get("start_time")
        })
    print(f"Finished player {i}. Matches collected so far: {len(all_player_matches)}")
    time.sleep(1)  # Delay between players

# Convert to DataFrame
df_players = pd.DataFrame(all_player_matches)

# Save to CSV
csv_path = r"C:\Users\Ellen\Desktop\OpenDota Data\player_match_data.csv"
df_players.to_csv(csv_path, index=False)
print(f"Saved {len(df_players)} rows to {csv_path}")
# Out:
# Fetching player match data...
# Fetching data for player 1 of 40 (account_id=103356886)...
# Finished player 1. Matches collected so far: 0
# Fetching data for player 2 of 40 (account_id=88596567)...
# Finished player 2. Matches collected so far: 0
# Fetching data for player 3 of 40 (account_id=146532881)...
# Finished player 3. Matches collected so far: 0
# Fetching data for player 4 of 40 (account_id=307648521)...
# Finished player 4. Matches collected so far: 0
# Fetching data for player 5 of 40 (account_id=29366434)...
# Finished player 5. Matches collected so far: 0
# Fetching data for player 6 of 40 (account_id=109362160)...
# Finished player 6. Matches collected so far: 0
# Fetching data for player 7 of 40 (account_id=200135497)...
# Finished player 7. Matches collected so far: 0
# Fetching data for player 8 of 40 (account_id=171627276)...
# Finished player 8. Matches collected so far: 0
# Fetching data for player 9 of 40 (account_id=103138418)...
# Finished player 9. Matches collected so far: 0
# Fetching data for player 10 of 40 (account_id=125774566)...
# Finished player 10. Matches collected so far: 0
# Fetching data for player 11 of 40 (account_id=104482314)...
# Finished player 11. Matches collected so far: 0
# Fetching data for player 12 of 40 (account_id=127763760)...
# Finished player 12. Matches collected so far: 0
# Fetching data for player 13 of 40 (account_id=175184565)...
# Finished player 13. Matches collected so far: 0
# Fetching data for player 14 of 40 (account_id=152883119)...
# Finished player 14. Matches collected so far: 0
# Fetching data for player 15 of 40 (account_id=105081622)...
# Finished player 15. Matches collected so far: 0
# Fetching data for player 16 of 40 (account_id=91444156)...
# Finished player 16. Matches collected so far: 0
# Fetching data for player 17 of 40 (account_id=107386895)...
# Finished player 17. Matches collected so far: 0
# Fetching data for player 18 of 40 (account_id=116905783)...
# Finished player 18. Matches collected so far: 0
# Fetching data for player 19 of 40 (account_id=156159900)...
# Finished player 19. Matches collected so far: 0
# Fetching data for player 20 of 40 (account_id=103231619)...
# Finished player 20. Matches collected so far: 0
# Fetching data for player 21 of 40 (account_id=130747907)...
# Finished player 21. Matches collected so far: 0
# Fetching data for player 22 of 40 (account_id=103980011)...
# Finished player 22. Matches collected so far: 0
# Fetching data for player 23 of 40 (account_id=110417858)...
# Finished player 23. Matches collected so far: 0
# Fetching data for player 24 of 40 (account_id=103226608)...
# Finished player 24. Matches collected so far: 0
# Fetching data for player 25 of 40 (account_id=108304393)...
# Finished player 25. Matches collected so far: 0
# Fetching data for player 26 of 40 (account_id=125108963)...
# Finished player 26. Matches collected so far: 0
# Fetching data for player 27 of 40 (account_id=146227106)...
# Finished player 27. Matches collected so far: 0
# Fetching data for player 28 of 40 (account_id=127499210)...
# Finished player 28. Matches collected so far: 0
# Fetching data for player 29 of 40 (account_id=87014496)...
# Finished player 29. Matches collected so far: 0
# Fetching data for player 30 of 40 (account_id=182008047)...
# Finished player 30. Matches collected so far: 0
# Fetching data for player 31 of 40 (account_id=139204898)...
# Finished player 31. Matches collected so far: 0
# Fetching data for player 32 of 40 (account_id=104496653)...
# Finished player 32. Matches collected so far: 0
# Fetching data for player 33 of 40 (account_id=126831383)...
# Finished player 33. Matches collected so far: 0
# Fetching data for player 34 of 40 (account_id=88522209)...
# Finished player 34. Matches collected so far: 0
# Fetching data for player 35 of 40 (account_id=111654271)...
# Finished player 35. Matches collected so far: 0
# Fetching data for player 36 of 40 (account_id=103432006)...
# Finished player 36. Matches collected so far: 0
# Fetching data for player 37 of 40 (account_id=111377393)...
# Finished player 37. Matches collected so far: 0
# Fetching data for player 38 of 40 (account_id=121074870)...
# Finished player 38. Matches collected so far: 0
# Fetching data for player 39 of 40 (account_id=101423931)...
# Finished player 39. Matches collected so far: 0
# Fetching data for player 40 of 40 (account_id=124203827)...
# Finished player 40. Matches collected so far: 0
# Saved 0 rows to C:\Users\Ellen\Desktop\OpenDota Data\player_match_data.csv

# %% [markdown]
# **Pull retry for (100 match stats)**

# %%
# Base URLs for OpenDota API
BASE_URL = "https://api.opendota.com/api"
MATCH_DETAIL_URL = f"{BASE_URL}/matches/{{match_id}}"

# --- Load your match IDs ---
matches_df = pd.read_csv(r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches.csv")
match_ids = matches_df['match_id'].unique()[:500]  # Take first 500 matches

def fetch_match_details(match_id):
    """
    Fetch detailed match data from OpenDota API.
    Handles 429 rate limit errors by waiting and retrying.
    """
    url = MATCH_DETAIL_URL.format(match_id=match_id)
    response = requests.get(url)

    # Handle rate limit (429)
    if response.status_code == 429:
        retry_after = int(response.headers.get('Retry-After', 60))
        print(f"Rate limit hit for match {match_id}. Retrying after {retry_after} seconds...")
        time.sleep(retry_after)
        response = requests.get(url)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching match {match_id}: {response.status_code}")
        return None

# --- Collect player stats ---
all_player_data = []
print("Fetching detailed match data...")
for i, match_id in enumerate(match_ids, start=1):
    print(f"Fetching match {i} of {len(match_ids)} (match_id={match_id})...")
    match_data = fetch_match_details(match_id)

    if match_data:
        for player in match_data.get("players", []):
            all_player_data.append({
                "match_id": match_id,
                "account_id": player.get("account_id"),
                "hero_id": player.get("hero_id"),
                "kills": player.get("kills"),
                "deaths": player.get("deaths"),
                "assists": player.get("assists"),
                "gold_per_min": player.get("gold_per_min"),
                "xp_per_min": player.get("xp_per_min"),
                "hero_damage": player.get("hero_damage"),
                "hero_healing": player.get("hero_healing"),
                "duration": match_data.get("duration"),
                "radiant_win": match_data.get("radiant_win"),
                "start_time": match_data.get("start_time")
            })

    time.sleep(1)  # Delay to avoid hitting rate limits

# --- Save to CSV ---
df_players = pd.DataFrame(all_player_data)
csv_path = r"C:\Users\Ellen\Desktop\OpenDota Data\match_details_subset.csv"
df_players.to_csv(csv_path, index=False)
print(f"Saved {len(df_players)} rows to {csv_path}")
# Out:
# Fetching detailed match data...
# Fetching match 1 of 101 (match_id=8390507617)...
# Fetching match 2 of 101 (match_id=8390507011)...
# Fetching match 3 of 101 (match_id=8390506011)...
# Fetching match 4 of 101 (match_id=8390503402)...
# Fetching match 5 of 101 (match_id=8390502507)...
# Fetching match 6 of 101 (match_id=8390502214)...
# Fetching match 7 of 101 (match_id=8390502015)...
# Fetching match 8 of 101 (match_id=8390500200)...
# Fetching match 9 of 101 (match_id=8390499919)...
# Fetching match 10 of 101 (match_id=8390499610)...
# Fetching match 11 of 101 (match_id=8390499003)...
# Fetching match 12 of 101 (match_id=8390498812)...
# Fetching match 13 of 101 (match_id=8390498502)...
# Fetching match 14 of 101 (match_id=8390498412)...
# Fetching match 15 of 101 (match_id=8390498303)...
# Fetching match 16 of 101 (match_id=8390497906)...
# Fetching match 17 of 101 (match_id=8390497704)...
# Fetching match 18 of 101 (match_id=8390497502)...
# Fetching match 19 of 101 (match_id=8390497004)...
# Fetching match 20 of 101 (match_id=8390496917)...
# Fetching match 21 of 101 (match_id=8390496914)...
# Fetching match 22 of 101 (match_id=8390496910)...
# Fetching match 23 of 101 (match_id=8390496816)...
# Fetching match 24 of 101 (match_id=8390496712)...
# Fetching match 25 of 101 (match_id=8390496618)...
# Fetching match 26 of 101 (match_id=8390496604)...
# Fetching match 27 of 101 (match_id=8390496412)...
# Fetching match 28 of 101 (match_id=8390496406)...
# Fetching match 29 of 101 (match_id=8390496317)...
# Fetching match 30 of 101 (match_id=8390496313)...
# Fetching match 31 of 101 (match_id=8390496206)...
# Fetching match 32 of 101 (match_id=8390496106)...
# Fetching match 33 of 101 (match_id=8390496013)...
# Fetching match 34 of 101 (match_id=8390496011)...
# Fetching match 35 of 101 (match_id=8390495911)...
# Fetching match 36 of 101 (match_id=8390495615)...
# Fetching match 37 of 101 (match_id=8390495610)...
# Fetching match 38 of 101 (match_id=8390495406)...
# Fetching match 39 of 101 (match_id=8390495203)...
# Fetching match 40 of 101 (match_id=8390495200)...
# Fetching match 41 of 101 (match_id=8390495105)...
# Fetching match 42 of 101 (match_id=8390495014)...
# Fetching match 43 of 101 (match_id=8390495012)...
# Fetching match 44 of 101 (match_id=8390494505)...
# Fetching match 45 of 101 (match_id=8390494417)...
# Fetching match 46 of 101 (match_id=8390494413)...
# Fetching match 47 of 101 (match_id=8390494411)...
# Fetching match 48 of 101 (match_id=8390494410)...
# Fetching match 49 of 101 (match_id=8390494409)...
# Fetching match 50 of 101 (match_id=8390494402)...
# Fetching match 51 of 101 (match_id=8390494400)...
# Fetching match 52 of 101 (match_id=8390494118)...
# Fetching match 53 of 101 (match_id=8390494106)...
# Fetching match 54 of 101 (match_id=8390494010)...
# Fetching match 55 of 101 (match_id=8390494003)...
# Fetching match 56 of 101 (match_id=8390493708)...
# Fetching match 57 of 101 (match_id=8390493707)...
# Fetching match 58 of 101 (match_id=8390493706)...
# Fetching match 59 of 101 (match_id=8390493619)...
# Fetching match 60 of 101 (match_id=8390493416)...
# Fetching match 61 of 101 (match_id=8390493406)...
# Fetching match 62 of 101 (match_id=8390493310)...
# Fetching match 63 of 101 (match_id=8390493204)...
# Fetching match 64 of 101 (match_id=8390493202)...
# Fetching match 65 of 101 (match_id=8390493201)...
# Fetching match 66 of 101 (match_id=8390493115)...
# Fetching match 67 of 101 (match_id=8390493008)...
# Fetching match 68 of 101 (match_id=8390493007)...
# Fetching match 69 of 101 (match_id=8390493000)...
# Fetching match 70 of 101 (match_id=8390492917)...
# Fetching match 71 of 101 (match_id=8390492817)...
# Fetching match 72 of 101 (match_id=8390492805)...
# Fetching match 73 of 101 (match_id=8390492705)...
# Fetching match 74 of 101 (match_id=8390492703)...
# Fetching match 75 of 101 (match_id=8390492701)...
# Fetching match 76 of 101 (match_id=8390492613)...
# Fetching match 77 of 101 (match_id=8390492602)...
# Fetching match 78 of 101 (match_id=8390492512)...
# Fetching match 79 of 101 (match_id=8390492414)...
# Fetching match 80 of 101 (match_id=8390492200)...
# Fetching match 81 of 101 (match_id=8390492115)...
# Fetching match 82 of 101 (match_id=8390492111)...
# Fetching match 83 of 101 (match_id=8390492104)...
# Fetching match 84 of 101 (match_id=8390492100)...
# Fetching match 85 of 101 (match_id=8390492019)...
# Fetching match 86 of 101 (match_id=8390492018)...
# Fetching match 87 of 101 (match_id=8390491913)...
# Fetching match 88 of 101 (match_id=8390491817)...
# Fetching match 89 of 101 (match_id=8390491615)...
# Fetching match 90 of 101 (match_id=8390491607)...
# Fetching match 91 of 101 (match_id=8390491500)...
# Fetching match 92 of 101 (match_id=8390491418)...
# Fetching match 93 of 101 (match_id=8390491413)...
# Fetching match 94 of 101 (match_id=8390491411)...
# Fetching match 95 of 101 (match_id=8390491407)...
# Fetching match 96 of 101 (match_id=8390491312)...
# Fetching match 97 of 101 (match_id=8390491309)...
# Fetching match 98 of 101 (match_id=8390491218)...
# Fetching match 99 of 101 (match_id=8390491203)...
# Fetching match 100 of 101 (match_id=8390491105)...
# Fetching match 101 of 101 (match_id=8390500308)...
# Saved 1010 rows to C:\Users\Ellen\Desktop\OpenDota Data\match_details_subset.csv

# %% [markdown]
# **Pull remaining 400 match stats**

# %%
import os

# File paths
matches_file = r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches.csv"
output_file = r"C:\Users\Ellen\Desktop\OpenDota Data\match_details_500matches.csv"

# Base URL for OpenDota API
BASE_URL = "https://api.opendota.com/api"
MATCH_DETAIL_URL = f"{BASE_URL}/matches/{{match_id}}"

# --- Load match IDs ---
all_matches_df = pd.read_csv(matches_file)
match_ids = all_matches_df['match_id'].unique()[:500]  # Top 500 matches

# --- Load existing output (if available) ---
if os.path.exists(output_file):
    existing_df = pd.read_csv(output_file)
    processed_matches = set(existing_df['match_id'].unique())
    print(f"Resuming: {len(processed_matches)} matches already processed, {len(existing_df)} rows in file.")
else:
    existing_df = pd.DataFrame()
    processed_matches = set()
    print("No existing file found. Starting fresh.")

# --- Find remaining matches ---
remaining_match_ids = [mid for mid in match_ids if mid not in processed_matches]
print(f"Remaining matches to fetch: {len(remaining_match_ids)}")

def fetch_match_details(match_id):
    url = MATCH_DETAIL_URL.format(match_id=match_id)
    response = requests.get(url)
    if response.status_code == 429:  # Handle rate limit
        retry_after = int(response.headers.get('Retry-After', 60))
        print(f"Rate limit hit. Waiting {retry_after} seconds...")
        time.sleep(retry_after)
        response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching match {match_id}: {response.status_code}")
        return None

# --- Fetch matches ---
all_new_data = []
total_rows = len(existing_df)  # Track row count from existing data

for i, match_id in enumerate(remaining_match_ids, start=1):
    print(f"Fetching match {i} of {len(remaining_match_ids)} (match_id={match_id})...")
    match_data = fetch_match_details(match_id)
    if match_data:
        player_rows = []
        for player in match_data.get("players", []):
            player_rows.append({
                "match_id": match_id,
                "account_id": player.get("account_id"),
                "hero_id": player.get("hero_id"),
                "kills": player.get("kills"),
                "deaths": player.get("deaths"),
                "assists": player.get("assists"),
                "gold_per_min": player.get("gold_per_min"),
                "xp_per_min": player.get("xp_per_min"),
                "hero_damage": player.get("hero_damage"),
                "hero_healing": player.get("hero_healing"),
                "duration": match_data.get("duration"),
                "radiant_win": match_data.get("radiant_win"),
                "start_time": match_data.get("start_time")
            })
        all_new_data.extend(player_rows)
        total_rows += len(player_rows)
        print(f" → Rows so far: {total_rows}")
    time.sleep(1)  # Prevent rate-limit

# --- Combine old + new data ---
if len(existing_df) > 0:
    final_df = pd.concat([existing_df, pd.DataFrame(all_new_data)], ignore_index=True)
else:
    final_df = pd.DataFrame(all_new_data)

# --- Save file ---
final_df.to_csv(output_file, index=False)
print(f"Saved {len(final_df)} rows to {output_file}")
print(f"Matches processed: {len(final_df['match_id'].unique())} of 500")
# Out:
# No existing file found. Starting fresh.
# Remaining matches to fetch: 101
# Fetching match 1 of 101 (match_id=8390507617)...
#  → Rows so far: 10
# Fetching match 2 of 101 (match_id=8390507011)...
#  → Rows so far: 20
# Fetching match 3 of 101 (match_id=8390506011)...
#  → Rows so far: 30
# Fetching match 4 of 101 (match_id=8390503402)...
#  → Rows so far: 40
# Fetching match 5 of 101 (match_id=8390502507)...
#  → Rows so far: 50
# Fetching match 6 of 101 (match_id=8390502214)...
#  → Rows so far: 60
# Fetching match 7 of 101 (match_id=8390502015)...
#  → Rows so far: 70
# Fetching match 8 of 101 (match_id=8390500200)...
#  → Rows so far: 80
# Fetching match 9 of 101 (match_id=8390499919)...
#  → Rows so far: 90
# Fetching match 10 of 101 (match_id=8390499610)...
#  → Rows so far: 100
# Fetching match 11 of 101 (match_id=8390499003)...
#  → Rows so far: 110
# Fetching match 12 of 101 (match_id=8390498812)...
#  → Rows so far: 120
# Fetching match 13 of 101 (match_id=8390498502)...
#  → Rows so far: 130
# Fetching match 14 of 101 (match_id=8390498412)...
#  → Rows so far: 140
# Fetching match 15 of 101 (match_id=8390498303)...
#  → Rows so far: 150
# Fetching match 16 of 101 (match_id=8390497906)...
#  → Rows so far: 160
# Fetching match 17 of 101 (match_id=8390497704)...
#  → Rows so far: 170
# Fetching match 18 of 101 (match_id=8390497502)...
#  → Rows so far: 180
# Fetching match 19 of 101 (match_id=8390497004)...
#  → Rows so far: 190
# Fetching match 20 of 101 (match_id=8390496917)...
#  → Rows so far: 200
# Fetching match 21 of 101 (match_id=8390496914)...
#  → Rows so far: 210
# Fetching match 22 of 101 (match_id=8390496910)...
#  → Rows so far: 220
# Fetching match 23 of 101 (match_id=8390496816)...
#  → Rows so far: 230
# Fetching match 24 of 101 (match_id=8390496712)...
#  → Rows so far: 240
# Fetching match 25 of 101 (match_id=8390496618)...
#  → Rows so far: 250
# Fetching match 26 of 101 (match_id=8390496604)...
#  → Rows so far: 260
# Fetching match 27 of 101 (match_id=8390496412)...
#  → Rows so far: 270
# Fetching match 28 of 101 (match_id=8390496406)...
#  → Rows so far: 280
# Fetching match 29 of 101 (match_id=8390496317)...
#  → Rows so far: 290
# Fetching match 30 of 101 (match_id=8390496313)...
#  → Rows so far: 300
# Fetching match 31 of 101 (match_id=8390496206)...
#  → Rows so far: 310
# Fetching match 32 of 101 (match_id=8390496106)...
#  → Rows so far: 320
# Fetching match 33 of 101 (match_id=8390496013)...
#  → Rows so far: 330
# Fetching match 34 of 101 (match_id=8390496011)...
#  → Rows so far: 340
# Fetching match 35 of 101 (match_id=8390495911)...
#  → Rows so far: 350
# Fetching match 36 of 101 (match_id=8390495615)...
#  → Rows so far: 360
# Fetching match 37 of 101 (match_id=8390495610)...
#  → Rows so far: 370
# Fetching match 38 of 101 (match_id=8390495406)...
#  → Rows so far: 380
# Fetching match 39 of 101 (match_id=8390495203)...
#  → Rows so far: 390
# Fetching match 40 of 101 (match_id=8390495200)...
#  → Rows so far: 400
# Fetching match 41 of 101 (match_id=8390495105)...
#  → Rows so far: 410
# Fetching match 42 of 101 (match_id=8390495014)...
#  → Rows so far: 420
# Fetching match 43 of 101 (match_id=8390495012)...
#  → Rows so far: 430
# Fetching match 44 of 101 (match_id=8390494505)...
#  → Rows so far: 440
# Fetching match 45 of 101 (match_id=8390494417)...
#  → Rows so far: 450
# Fetching match 46 of 101 (match_id=8390494413)...
#  → Rows so far: 460
# Fetching match 47 of 101 (match_id=8390494411)...
#  → Rows so far: 470
# Fetching match 48 of 101 (match_id=8390494410)...
#  → Rows so far: 480
# Fetching match 49 of 101 (match_id=8390494409)...
#  → Rows so far: 490
# Fetching match 50 of 101 (match_id=8390494402)...
#  → Rows so far: 500
# Fetching match 51 of 101 (match_id=8390494400)...
#  → Rows so far: 510
# Fetching match 52 of 101 (match_id=8390494118)...
#  → Rows so far: 520
# Fetching match 53 of 101 (match_id=8390494106)...
#  → Rows so far: 530
# Fetching match 54 of 101 (match_id=8390494010)...
#  → Rows so far: 540
# Fetching match 55 of 101 (match_id=8390494003)...
#  → Rows so far: 550
# Fetching match 56 of 101 (match_id=8390493708)...
#  → Rows so far: 560
# Fetching match 57 of 101 (match_id=8390493707)...
#  → Rows so far: 570
# Fetching match 58 of 101 (match_id=8390493706)...
#  → Rows so far: 580
# Fetching match 59 of 101 (match_id=8390493619)...
#  → Rows so far: 590
# Fetching match 60 of 101 (match_id=8390493416)...
#  → Rows so far: 600
# Fetching match 61 of 101 (match_id=8390493406)...
#  → Rows so far: 610
# Fetching match 62 of 101 (match_id=8390493310)...
#  → Rows so far: 620
# Fetching match 63 of 101 (match_id=8390493204)...
#  → Rows so far: 630
# Fetching match 64 of 101 (match_id=8390493202)...
#  → Rows so far: 640
# Fetching match 65 of 101 (match_id=8390493201)...
#  → Rows so far: 650
# Fetching match 66 of 101 (match_id=8390493115)...
#  → Rows so far: 660
# Fetching match 67 of 101 (match_id=8390493008)...
#  → Rows so far: 670
# Fetching match 68 of 101 (match_id=8390493007)...
#  → Rows so far: 680
# Fetching match 69 of 101 (match_id=8390493000)...
#  → Rows so far: 690
# Fetching match 70 of 101 (match_id=8390492917)...
#  → Rows so far: 700
# Fetching match 71 of 101 (match_id=8390492817)...
#  → Rows so far: 710
# Fetching match 72 of 101 (match_id=8390492805)...
#  → Rows so far: 720
# Fetching match 73 of 101 (match_id=8390492705)...
#  → Rows so far: 730
# Fetching match 74 of 101 (match_id=8390492703)...
#  → Rows so far: 740
# Fetching match 75 of 101 (match_id=8390492701)...
#  → Rows so far: 750
# Fetching match 76 of 101 (match_id=8390492613)...
#  → Rows so far: 760
# Fetching match 77 of 101 (match_id=8390492602)...
#  → Rows so far: 770
# Fetching match 78 of 101 (match_id=8390492512)...
#  → Rows so far: 780
# Fetching match 79 of 101 (match_id=8390492414)...
#  → Rows so far: 790
# Fetching match 80 of 101 (match_id=8390492200)...
#  → Rows so far: 800
# Fetching match 81 of 101 (match_id=8390492115)...
#  → Rows so far: 810
# Fetching match 82 of 101 (match_id=8390492111)...
#  → Rows so far: 820
# Fetching match 83 of 101 (match_id=8390492104)...
#  → Rows so far: 830
# Fetching match 84 of 101 (match_id=8390492100)...
#  → Rows so far: 840
# Fetching match 85 of 101 (match_id=8390492019)...
#  → Rows so far: 850
# Fetching match 86 of 101 (match_id=8390492018)...
#  → Rows so far: 860
# Fetching match 87 of 101 (match_id=8390491913)...
#  → Rows so far: 870
# Fetching match 88 of 101 (match_id=8390491817)...
#  → Rows so far: 880
# Fetching match 89 of 101 (match_id=8390491615)...
#  → Rows so far: 890
# Fetching match 90 of 101 (match_id=8390491607)...
#  → Rows so far: 900
# Fetching match 91 of 101 (match_id=8390491500)...
#  → Rows so far: 910
# Fetching match 92 of 101 (match_id=8390491418)...
#  → Rows so far: 920
# Fetching match 93 of 101 (match_id=8390491413)...
#  → Rows so far: 930
# Fetching match 94 of 101 (match_id=8390491411)...
#  → Rows so far: 940
# Fetching match 95 of 101 (match_id=8390491407)...
#  → Rows so far: 950
# Fetching match 96 of 101 (match_id=8390491312)...
#  → Rows so far: 960
# Fetching match 97 of 101 (match_id=8390491309)...
#  → Rows so far: 970
# Fetching match 98 of 101 (match_id=8390491218)...
#  → Rows so far: 980
# Fetching match 99 of 101 (match_id=8390491203)...
#  → Rows so far: 990
# Fetching match 100 of 101 (match_id=8390491105)...
#  → Rows so far: 1000
# Fetching match 101 of 101 (match_id=8390500308)...
#  → Rows so far: 1010
# Saved 1010 rows to C:\Users\Ellen\Desktop\OpenDota Data\match_details_500matches.csv
# Matches processed: 101 of 500

# %%
# --- Config ---
OUTPUT_FILE = r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches_500plus.csv"
NUM_BATCHES = 11   # 11 x 50 = 550 matches
DELAY = 1          # seconds between requests

BASE_URL = "https://api.opendota.com/api"
PUBLIC_MATCHES_URL = f"{BASE_URL}/publicMatches"

all_matches = []

print(f"Fetching {NUM_BATCHES * 50} match IDs from OpenDota...")
for batch in range(NUM_BATCHES):
    response = requests.get(PUBLIC_MATCHES_URL)
    if response.status_code == 200:
        data = response.json()
        all_matches.extend(data)
        print(f"Batch {batch+1}/{NUM_BATCHES}: Collected {len(data)} matches, total so far {len(all_matches)}")
    else:
        print(f"Error fetching batch {batch+1}: {response.status_code}")
    time.sleep(DELAY)

# --- Save to CSV ---
df_matches = pd.DataFrame(all_matches)
df_matches.drop_duplicates(subset=["match_id"], inplace=True)
df_matches.to_csv(OUTPUT_FILE, index=False)

print(f"Saved {len(df_matches)} unique match IDs to {OUTPUT_FILE}")
# Out:
# Fetching 550 match IDs from OpenDota...
# Batch 1/11: Collected 100 matches, total so far 100
# Batch 2/11: Collected 100 matches, total so far 200
# Batch 3/11: Collected 100 matches, total so far 300
# Batch 4/11: Collected 100 matches, total so far 400
# Batch 5/11: Collected 100 matches, total so far 500
# Batch 6/11: Collected 100 matches, total so far 600
# Batch 7/11: Collected 100 matches, total so far 700
# Batch 8/11: Collected 100 matches, total so far 800
# Batch 9/11: Collected 100 matches, total so far 900
# Batch 10/11: Collected 100 matches, total so far 1000
# Batch 11/11: Collected 100 matches, total so far 1100
# Saved 105 unique match IDs to C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches_500plus.csv

# %% [markdown]
# **1. Pagination script for 500 matches**

# %%
OUTPUT_FILE = r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches_500plus.csv"
NUM_BATCHES = 11   # ~550 matches
DELAY = 1

BASE_URL = "https://api.opendota.com/api/publicMatches"

all_matches = []
less_than_match_id = None

print(f"Fetching paginated matches from OpenDota ({NUM_BATCHES} batches)...")
for batch in range(NUM_BATCHES):
    params = {}
    if less_than_match_id:
        params["less_than_match_id"] = less_than_match_id

    response = requests.get(BASE_URL, params=params)
    if response.status_code == 200:
        data = response.json()
        if not data:
            print("No more matches returned by API.")
            break
        all_matches.extend(data)
        less_than_match_id = min(match["match_id"] for match in data)  # move pagination pointer
        print(f"Batch {batch+1}/{NUM_BATCHES}: Collected {len(data)} matches, total so far {len(all_matches)}")
    else:
        print(f"Error fetching batch {batch+1}: {response.status_code}")
    time.sleep(DELAY)

# Deduplicate and save
df_matches = pd.DataFrame(all_matches).drop_duplicates(subset=["match_id"])
df_matches.to_csv(OUTPUT_FILE, index=False)

print(f"Saved {len(df_matches)} unique match IDs to {OUTPUT_FILE}")
# Out:
# Fetching paginated matches from OpenDota (11 batches)...
# Batch 1/11: Collected 100 matches, total so far 100
# Batch 2/11: Collected 100 matches, total so far 200
# Batch 3/11: Collected 100 matches, total so far 300
# Batch 4/11: Collected 100 matches, total so far 400
# Batch 5/11: Collected 100 matches, total so far 500
# Batch 6/11: Collected 100 matches, total so far 600
# Batch 7/11: Collected 100 matches, total so far 700
# Batch 8/11: Collected 100 matches, total so far 800
# Batch 9/11: Collected 100 matches, total so far 900
# Batch 10/11: Collected 100 matches, total so far 1000
# Batch 11/11: Collected 100 matches, total so far 1100
# Saved 1100 unique match IDs to C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches_500plus.csv

# %% [markdown]
# **2. Resume-enabled match detail script**
# (Resume + Row Counter + New Match File)

# %%
# --- File paths ---
matches_file = r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches_500plus.csv"
output_file = r"C:\Users\Ellen\Desktop\OpenDota Data\match_details_500matches.csv"

# Base URL for OpenDota API
BASE_URL = "https://api.opendota.com/api"
MATCH_DETAIL_URL = f"{BASE_URL}/matches/{{match_id}}"

# --- Load match IDs ---
all_matches_df = pd.read_csv(matches_file)
match_ids = all_matches_df['match_id'].unique()[:500]

# --- Load existing output (if available) ---
if os.path.exists(output_file):
    existing_df = pd.read_csv(output_file)
    processed_matches = set(existing_df['match_id'].unique())
    print(f"Resuming: {len(processed_matches)} matches already processed, {len(existing_df)} rows in file.")
else:
    existing_df = pd.DataFrame()
    processed_matches = set()
    print("No existing file found. Starting fresh.")

# --- Find remaining matches ---
remaining_match_ids = [mid for mid in match_ids if mid not in processed_matches]
print(f"Remaining matches to fetch: {len(remaining_match_ids)}")

def fetch_match_details(match_id):
    url = MATCH_DETAIL_URL.format(match_id=match_id)
    response = requests.get(url)
    if response.status_code == 429:  # Rate limit handling
        retry_after = int(response.headers.get('Retry-After', 60))
        print(f"Rate limit hit. Waiting {retry_after} seconds...")
        time.sleep(retry_after)
        response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching match {match_id}: {response.status_code}")
        return None

# --- Fetch matches ---
all_new_data = []
total_rows = len(existing_df)

for i, match_id in enumerate(remaining_match_ids, start=1):
    print(f"Fetching match {i} of {len(remaining_match_ids)} (match_id={match_id})...")
    match_data = fetch_match_details(match_id)
    if match_data:
        player_rows = []
        for player in match_data.get("players", []):
            player_rows.append({
                "match_id": match_id,
                "account_id": player.get("account_id"),
                "hero_id": player.get("hero_id"),
                "kills": player.get("kills"),
                "deaths": player.get("deaths"),
                "assists": player.get("assists"),
                "gold_per_min": player.get("gold_per_min"),
                "xp_per_min": player.get("xp_per_min"),
                "hero_damage": player.get("hero_damage"),
                "hero_healing": player.get("hero_healing"),
                "duration": match_data.get("duration"),
                "radiant_win": match_data.get("radiant_win"),
                "start_time": match_data.get("start_time")
            })
        all_new_data.extend(player_rows)
        total_rows += len(player_rows)
        print(f" → Rows so far: {total_rows}")
    time.sleep(1)

# --- Combine old + new data ---
if len(existing_df) > 0:
    final_df = pd.concat([existing_df, pd.DataFrame(all_new_data)], ignore_index=True)
else:
    final_df = pd.DataFrame(all_new_data)

# --- Save file ---
final_df.to_csv(output_file, index=False)
print(f"Saved {len(final_df)} rows to {output_file}")
print(f"Matches processed: {len(final_df['match_id'].unique())} of 500")
# Out:
# Resuming: 101 matches already processed, 1010 rows in file.
# Remaining matches to fetch: 500
# Fetching match 1 of 500 (match_id=8391314512)...
#  → Rows so far: 1020
# Fetching match 2 of 500 (match_id=8391312415)...
#  → Rows so far: 1030
# Fetching match 3 of 500 (match_id=8391311716)...
#  → Rows so far: 1040
# Fetching match 4 of 500 (match_id=8391311417)...
#  → Rows so far: 1050
# Fetching match 5 of 500 (match_id=8391310813)...
#  → Rows so far: 1060
# Fetching match 6 of 500 (match_id=8391309804)...
#  → Rows so far: 1070
# Fetching match 7 of 500 (match_id=8391309707)...
#  → Rows so far: 1080
# Fetching match 8 of 500 (match_id=8391308918)...
#  → Rows so far: 1090
# Fetching match 9 of 500 (match_id=8391308906)...
#  → Rows so far: 1100
# Fetching match 10 of 500 (match_id=8391308717)...
#  → Rows so far: 1110
# Fetching match 11 of 500 (match_id=8391308506)...
#  → Rows so far: 1120
# Fetching match 12 of 500 (match_id=8391307704)...
#  → Rows so far: 1130
# Fetching match 13 of 500 (match_id=8391306714)...
#  → Rows so far: 1140
# Fetching match 14 of 500 (match_id=8391306114)...
#  → Rows so far: 1150
# Fetching match 15 of 500 (match_id=8391305206)...
#  → Rows so far: 1160
# Fetching match 16 of 500 (match_id=8391304604)...
#  → Rows so far: 1170
# Fetching match 17 of 500 (match_id=8391304417)...
#  → Rows so far: 1180
# Fetching match 18 of 500 (match_id=8391304205)...
#  → Rows so far: 1190
# Fetching match 19 of 500 (match_id=8391303705)...
#  → Rows so far: 1200
# Fetching match 20 of 500 (match_id=8391303704)...
#  → Rows so far: 1210
# Fetching match 21 of 500 (match_id=8391303518)...
#  → Rows so far: 1220
# Fetching match 22 of 500 (match_id=8391303401)...
#  → Rows so far: 1230
# Fetching match 23 of 500 (match_id=8391303306)...
#  → Rows so far: 1240
# Fetching match 24 of 500 (match_id=8391303208)...
#  → Rows so far: 1250
# Fetching match 25 of 500 (match_id=8391303110)...
#  → Rows so far: 1260
# Fetching match 26 of 500 (match_id=8391303016)...
#  → Rows so far: 1270
# Fetching match 27 of 500 (match_id=8391302914)...
#  → Rows so far: 1280
# Fetching match 28 of 500 (match_id=8391302812)...
#  → Rows so far: 1290
# Fetching match 29 of 500 (match_id=8391302703)...
#  → Rows so far: 1300
# Fetching match 30 of 500 (match_id=8391302606)...
#  → Rows so far: 1310
# Fetching match 31 of 500 (match_id=8391302604)...
#  → Rows so far: 1320
# Fetching match 32 of 500 (match_id=8391302415)...
#  → Rows so far: 1330
# Fetching match 33 of 500 (match_id=8391302217)...
#  → Rows so far: 1340
# Fetching match 34 of 500 (match_id=8391302109)...
#  → Rows so far: 1350
# Fetching match 35 of 500 (match_id=8391301914)...
#  → Rows so far: 1360
# Fetching match 36 of 500 (match_id=8391301803)...
#  → Rows so far: 1370
# Fetching match 37 of 500 (match_id=8391301018)...
#  → Rows so far: 1380
# Fetching match 38 of 500 (match_id=8391301017)...
#  → Rows so far: 1390
# Fetching match 39 of 500 (match_id=8391300608)...
#  → Rows so far: 1400
# Fetching match 40 of 500 (match_id=8391300604)...
#  → Rows so far: 1410
# Fetching match 41 of 500 (match_id=8391300513)...
#  → Rows so far: 1420
# Fetching match 42 of 500 (match_id=8391300412)...
#  → Rows so far: 1430
# Fetching match 43 of 500 (match_id=8391300405)...
#  → Rows so far: 1440
# Fetching match 44 of 500 (match_id=8391300219)...
#  → Rows so far: 1450
# Fetching match 45 of 500 (match_id=8391300203)...
#  → Rows so far: 1460
# Fetching match 46 of 500 (match_id=8391300006)...
#  → Rows so far: 1470
# Fetching match 47 of 500 (match_id=8391299910)...
#  → Rows so far: 1480
# Fetching match 48 of 500 (match_id=8391299908)...
#  → Rows so far: 1490
# Fetching match 49 of 500 (match_id=8391299713)...
#  → Rows so far: 1500
# Fetching match 50 of 500 (match_id=8391299619)...
#  → Rows so far: 1510
# Fetching match 51 of 500 (match_id=8391299617)...
#  → Rows so far: 1520
# Fetching match 52 of 500 (match_id=8391299414)...
#  → Rows so far: 1530
# Fetching match 53 of 500 (match_id=8391299303)...
#  → Rows so far: 1540
# Fetching match 54 of 500 (match_id=8391299007)...
#  → Rows so far: 1550
# Fetching match 55 of 500 (match_id=8391298811)...
#  → Rows so far: 1560
# Fetching match 56 of 500 (match_id=8391298710)...
#  → Rows so far: 1570
# Fetching match 57 of 500 (match_id=8391298707)...
#  → Rows so far: 1580
# Fetching match 58 of 500 (match_id=8391298612)...
#  → Rows so far: 1590
# Fetching match 59 of 500 (match_id=8391298117)...
#  → Rows so far: 1600
# Fetching match 60 of 500 (match_id=8391298104)...
#  → Rows so far: 1610
# Fetching match 61 of 500 (match_id=8391298100)...
#  → Rows so far: 1620
# Fetching match 62 of 500 (match_id=8391298015)...
#  → Rows so far: 1630
# Fetching match 63 of 500 (match_id=8391298008)...
#  → Rows so far: 1640
# Fetching match 64 of 500 (match_id=8391298002)...
#  → Rows so far: 1650
# Fetching match 65 of 500 (match_id=8391297813)...
#  → Rows so far: 1660
# Fetching match 66 of 500 (match_id=8391297811)...
#  → Rows so far: 1670
# Fetching match 67 of 500 (match_id=8391297808)...
#  → Rows so far: 1680
# Fetching match 68 of 500 (match_id=8391297807)...
#  → Rows so far: 1690
# Fetching match 69 of 500 (match_id=8391297804)...
#  → Rows so far: 1700
# Fetching match 70 of 500 (match_id=8391297716)...
#  → Rows so far: 1710
# Fetching match 71 of 500 (match_id=8391297714)...
#  → Rows so far: 1720
# Fetching match 72 of 500 (match_id=8391297710)...
#  → Rows so far: 1730
# Fetching match 73 of 500 (match_id=8391297707)...
#  → Rows so far: 1740
# Fetching match 74 of 500 (match_id=8391297703)...
#  → Rows so far: 1750
# Fetching match 75 of 500 (match_id=8391297619)...
#  → Rows so far: 1760
# Fetching match 76 of 500 (match_id=8391297607)...
#  → Rows so far: 1770
# Fetching match 77 of 500 (match_id=8391297604)...
#  → Rows so far: 1780
# Fetching match 78 of 500 (match_id=8391297509)...
#  → Rows so far: 1790
# Fetching match 79 of 500 (match_id=8391297409)...
#  → Rows so far: 1800
# Fetching match 80 of 500 (match_id=8391297317)...
#  → Rows so far: 1810
# Fetching match 81 of 500 (match_id=8391297308)...
#  → Rows so far: 1820
# Fetching match 82 of 500 (match_id=8391297307)...
#  → Rows so far: 1830
# Fetching match 83 of 500 (match_id=8391297214)...
#  → Rows so far: 1840
# Fetching match 84 of 500 (match_id=8391297103)...
#  → Rows so far: 1850
# Fetching match 85 of 500 (match_id=8391297019)...
# Rate limit hit. Waiting 60 seconds...
#  → Rows so far: 1860
# Fetching match 86 of 500 (match_id=8391297013)...
#  → Rows so far: 1870
# Fetching match 87 of 500 (match_id=8391297001)...
#  → Rows so far: 1880
# Fetching match 88 of 500 (match_id=8391296915)...
#  → Rows so far: 1890
# Fetching match 89 of 500 (match_id=8391296901)...
#  → Rows so far: 1900
# Fetching match 90 of 500 (match_id=8391296705)...
#  → Rows so far: 1910
# Fetching match 91 of 500 (match_id=8391296616)...
#  → Rows so far: 1920
# Fetching match 92 of 500 (match_id=8391296613)...
#  → Rows so far: 1930
# Fetching match 93 of 500 (match_id=8391296307)...
#  → Rows so far: 1940
# Fetching match 94 of 500 (match_id=8391296210)...
#  → Rows so far: 1950
# Fetching match 95 of 500 (match_id=8391295912)...
#  → Rows so far: 1960
# Fetching match 96 of 500 (match_id=8391295815)...
#  → Rows so far: 1970
# Fetching match 97 of 500 (match_id=8391295813)...
#  → Rows so far: 1980
# Fetching match 98 of 500 (match_id=8391295614)...
#  → Rows so far: 1990
# Fetching match 99 of 500 (match_id=8391295610)...
#  → Rows so far: 2000
# Fetching match 100 of 500 (match_id=8391295514)...
#  → Rows so far: 2010
# Fetching match 101 of 500 (match_id=8391295415)...
#  → Rows so far: 2020
# Fetching match 102 of 500 (match_id=8391295410)...
#  → Rows so far: 2030
# Fetching match 103 of 500 (match_id=8391295400)...
#  → Rows so far: 2040
# Fetching match 104 of 500 (match_id=8391295308)...
#  → Rows so far: 2050
# Fetching match 105 of 500 (match_id=8391295307)...
#  → Rows so far: 2060
# Fetching match 106 of 500 (match_id=8391295207)...
#  → Rows so far: 2070
# Fetching match 107 of 500 (match_id=8391295205)...
#  → Rows so far: 2080
# Fetching match 108 of 500 (match_id=8391295118)...
#  → Rows so far: 2090
# Fetching match 109 of 500 (match_id=8391295017)...
#  → Rows so far: 2100
# Fetching match 110 of 500 (match_id=8391295013)...
#  → Rows so far: 2110
# Fetching match 111 of 500 (match_id=8391294912)...
#  → Rows so far: 2120
# Fetching match 112 of 500 (match_id=8391294909)...
#  → Rows so far: 2130
# Fetching match 113 of 500 (match_id=8391294908)...
#  → Rows so far: 2140
# Fetching match 114 of 500 (match_id=8391294819)...
#  → Rows so far: 2150
# Fetching match 115 of 500 (match_id=8391294817)...
#  → Rows so far: 2160
# Fetching match 116 of 500 (match_id=8391294803)...
#  → Rows so far: 2170
# Fetching match 117 of 500 (match_id=8391294702)...
#  → Rows so far: 2180
# Fetching match 118 of 500 (match_id=8391294605)...
#  → Rows so far: 2190
# Fetching match 119 of 500 (match_id=8391294508)...
#  → Rows so far: 2200
# Fetching match 120 of 500 (match_id=8391294506)...
#  → Rows so far: 2210
# Fetching match 121 of 500 (match_id=8391294411)...
#  → Rows so far: 2220
# Fetching match 122 of 500 (match_id=8391294409)...
#  → Rows so far: 2230
# Fetching match 123 of 500 (match_id=8391294316)...
#  → Rows so far: 2240
# Fetching match 124 of 500 (match_id=8391294219)...
#  → Rows so far: 2250
# Fetching match 125 of 500 (match_id=8391294207)...
#  → Rows so far: 2260
# Fetching match 126 of 500 (match_id=8391294109)...
#  → Rows so far: 2270
# Fetching match 127 of 500 (match_id=8391294018)...
#  → Rows so far: 2280
# Fetching match 128 of 500 (match_id=8391294001)...
#  → Rows so far: 2290
# Fetching match 129 of 500 (match_id=8391293907)...
#  → Rows so far: 2300
# Fetching match 130 of 500 (match_id=8391293906)...
#  → Rows so far: 2310
# Fetching match 131 of 500 (match_id=8391293904)...
#  → Rows so far: 2320
# Fetching match 132 of 500 (match_id=8391293902)...
#  → Rows so far: 2330
# Fetching match 133 of 500 (match_id=8391293807)...
#  → Rows so far: 2340
# Fetching match 134 of 500 (match_id=8391293803)...
#  → Rows so far: 2350
# Fetching match 135 of 500 (match_id=8391293703)...
#  → Rows so far: 2360
# Fetching match 136 of 500 (match_id=8391293701)...
#  → Rows so far: 2370
# Fetching match 137 of 500 (match_id=8391293614)...
#  → Rows so far: 2380
# Fetching match 138 of 500 (match_id=8391293604)...
#  → Rows so far: 2390
# Fetching match 139 of 500 (match_id=8391293518)...
#  → Rows so far: 2400
# Fetching match 140 of 500 (match_id=8391293505)...
#  → Rows so far: 2410
# Fetching match 141 of 500 (match_id=8391293403)...
#  → Rows so far: 2420
# Fetching match 142 of 500 (match_id=8391293401)...
#  → Rows so far: 2430
# Fetching match 143 of 500 (match_id=8391293318)...
#  → Rows so far: 2440
# Fetching match 144 of 500 (match_id=8391293218)...
#  → Rows so far: 2450
# Fetching match 145 of 500 (match_id=8391293217)...
#  → Rows so far: 2460
# Fetching match 146 of 500 (match_id=8391293216)...
#  → Rows so far: 2470
# Fetching match 147 of 500 (match_id=8391293108)...
#  → Rows so far: 2480
# Fetching match 148 of 500 (match_id=8391293100)...
#  → Rows so far: 2490
# Fetching match 149 of 500 (match_id=8391293015)...
#  → Rows so far: 2500
# Fetching match 150 of 500 (match_id=8391293010)...
#  → Rows so far: 2510
# Fetching match 151 of 500 (match_id=8391292815)...
#  → Rows so far: 2520
# Fetching match 152 of 500 (match_id=8391292814)...
#  → Rows so far: 2530
# Fetching match 153 of 500 (match_id=8391292813)...
#  → Rows so far: 2540
# Fetching match 154 of 500 (match_id=8391292718)...
#  → Rows so far: 2550
# Fetching match 155 of 500 (match_id=8391292704)...
#  → Rows so far: 2560
# Fetching match 156 of 500 (match_id=8391292602)...
#  → Rows so far: 2570
# Fetching match 157 of 500 (match_id=8391292600)...
#  → Rows so far: 2580
# Fetching match 158 of 500 (match_id=8391292510)...
#  → Rows so far: 2590
# Fetching match 159 of 500 (match_id=8391292506)...
#  → Rows so far: 2600
# Fetching match 160 of 500 (match_id=8391292417)...
#  → Rows so far: 2610
# Fetching match 161 of 500 (match_id=8391292416)...
#  → Rows so far: 2620
# Fetching match 162 of 500 (match_id=8391292414)...
#  → Rows so far: 2630
# Fetching match 163 of 500 (match_id=8391292413)...
#  → Rows so far: 2640
# Fetching match 164 of 500 (match_id=8391292412)...
#  → Rows so far: 2650
# Fetching match 165 of 500 (match_id=8391292213)...
#  → Rows so far: 2660
# Fetching match 166 of 500 (match_id=8391292119)...
#  → Rows so far: 2670
# Fetching match 167 of 500 (match_id=8391292117)...
#  → Rows so far: 2680
# Fetching match 168 of 500 (match_id=8391292104)...
#  → Rows so far: 2690
# Fetching match 169 of 500 (match_id=8391292019)...
#  → Rows so far: 2700
# Fetching match 170 of 500 (match_id=8391292013)...
#  → Rows so far: 2710
# Fetching match 171 of 500 (match_id=8391292003)...
#  → Rows so far: 2720
# Fetching match 172 of 500 (match_id=8391291901)...
#  → Rows so far: 2730
# Fetching match 173 of 500 (match_id=8391291819)...
#  → Rows so far: 2740
# Fetching match 174 of 500 (match_id=8391291815)...
#  → Rows so far: 2750
# Fetching match 175 of 500 (match_id=8391291809)...
#  → Rows so far: 2760
# Fetching match 176 of 500 (match_id=8391291802)...
#  → Rows so far: 2770
# Fetching match 177 of 500 (match_id=8391291801)...
#  → Rows so far: 2780
# Fetching match 178 of 500 (match_id=8391291719)...
#  → Rows so far: 2790
# Fetching match 179 of 500 (match_id=8391291715)...
#  → Rows so far: 2800
# Fetching match 180 of 500 (match_id=8391291712)...
#  → Rows so far: 2810
# Fetching match 181 of 500 (match_id=8391291703)...
#  → Rows so far: 2820
# Fetching match 182 of 500 (match_id=8391291610)...
#  → Rows so far: 2830
# Fetching match 183 of 500 (match_id=8391291605)...
#  → Rows so far: 2840
# Fetching match 184 of 500 (match_id=8391291507)...
#  → Rows so far: 2850
# Fetching match 185 of 500 (match_id=8391291504)...
#  → Rows so far: 2860
# Fetching match 186 of 500 (match_id=8391291412)...
#  → Rows so far: 2870
# Fetching match 187 of 500 (match_id=8391291410)...
#  → Rows so far: 2880
# Fetching match 188 of 500 (match_id=8391291407)...
#  → Rows so far: 2890
# Fetching match 189 of 500 (match_id=8391291303)...
#  → Rows so far: 2900
# Fetching match 190 of 500 (match_id=8391291210)...
#  → Rows so far: 2910
# Fetching match 191 of 500 (match_id=8391291118)...
#  → Rows so far: 2920
# Fetching match 192 of 500 (match_id=8391291117)...
#  → Rows so far: 2930
# Fetching match 193 of 500 (match_id=8391291116)...
#  → Rows so far: 2940
# Fetching match 194 of 500 (match_id=8391291115)...
#  → Rows so far: 2950
# Fetching match 195 of 500 (match_id=8391291009)...
#  → Rows so far: 2960
# Fetching match 196 of 500 (match_id=8391291005)...
#  → Rows so far: 2970
# Fetching match 197 of 500 (match_id=8391290917)...
#  → Rows so far: 2980
# Fetching match 198 of 500 (match_id=8391290913)...
#  → Rows so far: 2990
# Fetching match 199 of 500 (match_id=8391290812)...
#  → Rows so far: 3000
# Fetching match 200 of 500 (match_id=8391290712)...
#  → Rows so far: 3010
# Fetching match 201 of 500 (match_id=8391290709)...
#  → Rows so far: 3020
# Fetching match 202 of 500 (match_id=8391290705)...
#  → Rows so far: 3030
# Fetching match 203 of 500 (match_id=8391290614)...
#  → Rows so far: 3040
# Fetching match 204 of 500 (match_id=8391290512)...
#  → Rows so far: 3050
# Fetching match 205 of 500 (match_id=8391290501)...
#  → Rows so far: 3060
# Fetching match 206 of 500 (match_id=8391290413)...
#  → Rows so far: 3070
# Fetching match 207 of 500 (match_id=8391290411)...
#  → Rows so far: 3080
# Fetching match 208 of 500 (match_id=8391290409)...
#  → Rows so far: 3090
# Fetching match 209 of 500 (match_id=8391290408)...
#  → Rows so far: 3100
# Fetching match 210 of 500 (match_id=8391290317)...
#  → Rows so far: 3110
# Fetching match 211 of 500 (match_id=8391290315)...
#  → Rows so far: 3120
# Fetching match 212 of 500 (match_id=8391290213)...
#  → Rows so far: 3130
# Fetching match 213 of 500 (match_id=8391290210)...
#  → Rows so far: 3140
# Fetching match 214 of 500 (match_id=8391290208)...
#  → Rows so far: 3150
# Fetching match 215 of 500 (match_id=8391290118)...
#  → Rows so far: 3160
# Fetching match 216 of 500 (match_id=8391290105)...
#  → Rows so far: 3170
# Fetching match 217 of 500 (match_id=8391290103)...
#  → Rows so far: 3180
# Fetching match 218 of 500 (match_id=8391290102)...
#  → Rows so far: 3190
# Fetching match 219 of 500 (match_id=8391290014)...
#  → Rows so far: 3200
# Fetching match 220 of 500 (match_id=8391290012)...
#  → Rows so far: 3210
# Fetching match 221 of 500 (match_id=8391290009)...
#  → Rows so far: 3220
# Fetching match 222 of 500 (match_id=8391290007)...
#  → Rows so far: 3230
# Fetching match 223 of 500 (match_id=8391290006)...
#  → Rows so far: 3240
# Fetching match 224 of 500 (match_id=8391289913)...
#  → Rows so far: 3250
# Fetching match 225 of 500 (match_id=8391289912)...
#  → Rows so far: 3260
# Fetching match 226 of 500 (match_id=8391289910)...
#  → Rows so far: 3270
# Fetching match 227 of 500 (match_id=8391289908)...
#  → Rows so far: 3280
# Fetching match 228 of 500 (match_id=8391289817)...
#  → Rows so far: 3290
# Fetching match 229 of 500 (match_id=8391289813)...
#  → Rows so far: 3300
# Fetching match 230 of 500 (match_id=8391289708)...
#  → Rows so far: 3310
# Fetching match 231 of 500 (match_id=8391289706)...
#  → Rows so far: 3320
# Fetching match 232 of 500 (match_id=8391289701)...
#  → Rows so far: 3330
# Fetching match 233 of 500 (match_id=8391289613)...
#  → Rows so far: 3340
# Fetching match 234 of 500 (match_id=8391289604)...
#  → Rows so far: 3350
# Fetching match 235 of 500 (match_id=8391289513)...
#  → Rows so far: 3360
# Fetching match 236 of 500 (match_id=8391289512)...
#  → Rows so far: 3370
# Fetching match 237 of 500 (match_id=8391289507)...
#  → Rows so far: 3380
# Fetching match 238 of 500 (match_id=8391289506)...
#  → Rows so far: 3390
# Fetching match 239 of 500 (match_id=8391289505)...
#  → Rows so far: 3400
# Fetching match 240 of 500 (match_id=8391289408)...
#  → Rows so far: 3410
# Fetching match 241 of 500 (match_id=8391289406)...
#  → Rows so far: 3420
# Fetching match 242 of 500 (match_id=8391289405)...
#  → Rows so far: 3430
# Fetching match 243 of 500 (match_id=8391289404)...
#  → Rows so far: 3440
# Fetching match 244 of 500 (match_id=8391289403)...
#  → Rows so far: 3450
# Fetching match 245 of 500 (match_id=8391289305)...
#  → Rows so far: 3460
# Fetching match 246 of 500 (match_id=8391289209)...
#  → Rows so far: 3470
# Fetching match 247 of 500 (match_id=8391289208)...
#  → Rows so far: 3480
# Fetching match 248 of 500 (match_id=8391289205)...
#  → Rows so far: 3490
# Fetching match 249 of 500 (match_id=8391289200)...
#  → Rows so far: 3500
# Fetching match 250 of 500 (match_id=8391289105)...
#  → Rows so far: 3510
# Fetching match 251 of 500 (match_id=8391289103)...
#  → Rows so far: 3520
# Fetching match 252 of 500 (match_id=8391289102)...
#  → Rows so far: 3530
# Fetching match 253 of 500 (match_id=8391289015)...
#  → Rows so far: 3540
# Fetching match 254 of 500 (match_id=8391289002)...
#  → Rows so far: 3550
# Fetching match 255 of 500 (match_id=8391289000)...
#  → Rows so far: 3560
# Fetching match 256 of 500 (match_id=8391288913)...
#  → Rows so far: 3570
# Fetching match 257 of 500 (match_id=8391288911)...
#  → Rows so far: 3580
# Fetching match 258 of 500 (match_id=8391288905)...
#  → Rows so far: 3590
# Fetching match 259 of 500 (match_id=8391288903)...
#  → Rows so far: 3600
# Fetching match 260 of 500 (match_id=8391288901)...
#  → Rows so far: 3610
# Fetching match 261 of 500 (match_id=8391288808)...
#  → Rows so far: 3620
# Fetching match 262 of 500 (match_id=8391288807)...
#  → Rows so far: 3630
# Fetching match 263 of 500 (match_id=8391288805)...
#  → Rows so far: 3640
# Fetching match 264 of 500 (match_id=8391288802)...
#  → Rows so far: 3650
# Fetching match 265 of 500 (match_id=8391288716)...
#  → Rows so far: 3660
# Fetching match 266 of 500 (match_id=8391288705)...
#  → Rows so far: 3670
# Fetching match 267 of 500 (match_id=8391288608)...
#  → Rows so far: 3680
# Fetching match 268 of 500 (match_id=8391288606)...
#  → Rows so far: 3690
# Fetching match 269 of 500 (match_id=8391288602)...
#  → Rows so far: 3700
# Fetching match 270 of 500 (match_id=8391288515)...
#  → Rows so far: 3710
# Fetching match 271 of 500 (match_id=8391288513)...
#  → Rows so far: 3720
# Fetching match 272 of 500 (match_id=8391288509)...
#  → Rows so far: 3730
# Fetching match 273 of 500 (match_id=8391288508)...
#  → Rows so far: 3740
# Fetching match 274 of 500 (match_id=8391288506)...
#  → Rows so far: 3750
# Fetching match 275 of 500 (match_id=8391288418)...
#  → Rows so far: 3760
# Fetching match 276 of 500 (match_id=8391288319)...
#  → Rows so far: 3770
# Fetching match 277 of 500 (match_id=8391288305)...
#  → Rows so far: 3780
# Fetching match 278 of 500 (match_id=8391288207)...
#  → Rows so far: 3790
# Fetching match 279 of 500 (match_id=8391288206)...
#  → Rows so far: 3800
# Fetching match 280 of 500 (match_id=8391288204)...
#  → Rows so far: 3810
# Fetching match 281 of 500 (match_id=8391288203)...
#  → Rows so far: 3820
# Fetching match 282 of 500 (match_id=8391288202)...
#  → Rows so far: 3830
# Fetching match 283 of 500 (match_id=8391288201)...
#  → Rows so far: 3840
# Fetching match 284 of 500 (match_id=8391288200)...
#  → Rows so far: 3850
# Fetching match 285 of 500 (match_id=8391288112)...
#  → Rows so far: 3860
# Fetching match 286 of 500 (match_id=8391288111)...
#  → Rows so far: 3870
# Fetching match 287 of 500 (match_id=8391288106)...
#  → Rows so far: 3880
# Fetching match 288 of 500 (match_id=8391288105)...
#  → Rows so far: 3890
# Fetching match 289 of 500 (match_id=8391288007)...
#  → Rows so far: 3900
# Fetching match 290 of 500 (match_id=8391288003)...
#  → Rows so far: 3910
# Fetching match 291 of 500 (match_id=8391288001)...
#  → Rows so far: 3920
# Fetching match 292 of 500 (match_id=8391287917)...
#  → Rows so far: 3930
# Fetching match 293 of 500 (match_id=8391287906)...
#  → Rows so far: 3940
# Fetching match 294 of 500 (match_id=8391287905)...
#  → Rows so far: 3950
# Fetching match 295 of 500 (match_id=8391287810)...
#  → Rows so far: 3960
# Fetching match 296 of 500 (match_id=8391287809)...
#  → Rows so far: 3970
# Fetching match 297 of 500 (match_id=8391287807)...
#  → Rows so far: 3980
# Fetching match 298 of 500 (match_id=8391287719)...
#  → Rows so far: 3990
# Fetching match 299 of 500 (match_id=8391287715)...
#  → Rows so far: 4000
# Fetching match 300 of 500 (match_id=8391287618)...
#  → Rows so far: 4010
# Fetching match 301 of 500 (match_id=8391287613)...
#  → Rows so far: 4020
# Fetching match 302 of 500 (match_id=8391287611)...
#  → Rows so far: 4030
# Fetching match 303 of 500 (match_id=8391287515)...
#  → Rows so far: 4040
# Fetching match 304 of 500 (match_id=8391287512)...
#  → Rows so far: 4050
# Fetching match 305 of 500 (match_id=8391287511)...
#  → Rows so far: 4060
# Fetching match 306 of 500 (match_id=8391287501)...
#  → Rows so far: 4070
# Fetching match 307 of 500 (match_id=8391287418)...
#  → Rows so far: 4080
# Fetching match 308 of 500 (match_id=8391287417)...
#  → Rows so far: 4090
# Fetching match 309 of 500 (match_id=8391287319)...
#  → Rows so far: 4100
# Fetching match 310 of 500 (match_id=8391287317)...
#  → Rows so far: 4110
# Fetching match 311 of 500 (match_id=8391287313)...
#  → Rows so far: 4120
# Fetching match 312 of 500 (match_id=8391287215)...
#  → Rows so far: 4130
# Fetching match 313 of 500 (match_id=8391287214)...
#  → Rows so far: 4140
# Fetching match 314 of 500 (match_id=8391287201)...
#  → Rows so far: 4150
# Fetching match 315 of 500 (match_id=8391287115)...
#  → Rows so far: 4160
# Fetching match 316 of 500 (match_id=8391287113)...
#  → Rows so far: 4170
# Fetching match 317 of 500 (match_id=8391287106)...
#  → Rows so far: 4180
# Fetching match 318 of 500 (match_id=8391287015)...
#  → Rows so far: 4190
# Fetching match 319 of 500 (match_id=8391287000)...
#  → Rows so far: 4200
# Fetching match 320 of 500 (match_id=8391286919)...
#  → Rows so far: 4210
# Fetching match 321 of 500 (match_id=8391286915)...
#  → Rows so far: 4220
# Fetching match 322 of 500 (match_id=8391286913)...
#  → Rows so far: 4230
# Fetching match 323 of 500 (match_id=8391286910)...
#  → Rows so far: 4240
# Fetching match 324 of 500 (match_id=8391286817)...
#  → Rows so far: 4250
# Fetching match 325 of 500 (match_id=8391286814)...
#  → Rows so far: 4260
# Fetching match 326 of 500 (match_id=8391286805)...
#  → Rows so far: 4270
# Fetching match 327 of 500 (match_id=8391286800)...
#  → Rows so far: 4280
# Fetching match 328 of 500 (match_id=8391286714)...
#  → Rows so far: 4290
# Fetching match 329 of 500 (match_id=8391286713)...
#  → Rows so far: 4300
# Fetching match 330 of 500 (match_id=8391286707)...
#  → Rows so far: 4310
# Fetching match 331 of 500 (match_id=8391286617)...
#  → Rows so far: 4320
# Fetching match 332 of 500 (match_id=8391286615)...
#  → Rows so far: 4330
# Fetching match 333 of 500 (match_id=8391286611)...
#  → Rows so far: 4340
# Fetching match 334 of 500 (match_id=8391286608)...
#  → Rows so far: 4350
# Fetching match 335 of 500 (match_id=8391286605)...
#  → Rows so far: 4360
# Fetching match 336 of 500 (match_id=8391286509)...
#  → Rows so far: 4370
# Fetching match 337 of 500 (match_id=8391286410)...
#  → Rows so far: 4380
# Fetching match 338 of 500 (match_id=8391286319)...
#  → Rows so far: 4390
# Fetching match 339 of 500 (match_id=8391286306)...
#  → Rows so far: 4400
# Fetching match 340 of 500 (match_id=8391286301)...
#  → Rows so far: 4410
# Fetching match 341 of 500 (match_id=8391286201)...
#  → Rows so far: 4420
# Fetching match 342 of 500 (match_id=8391286118)...
#  → Rows so far: 4430
# Fetching match 343 of 500 (match_id=8391286107)...
#  → Rows so far: 4440
# Fetching match 344 of 500 (match_id=8391286106)...
#  → Rows so far: 4450
# Fetching match 345 of 500 (match_id=8391286105)...
#  → Rows so far: 4460
# Fetching match 346 of 500 (match_id=8391286103)...
#  → Rows so far: 4470
# Fetching match 347 of 500 (match_id=8391286006)...
#  → Rows so far: 4480
# Fetching match 348 of 500 (match_id=8391286002)...
#  → Rows so far: 4490
# Fetching match 349 of 500 (match_id=8391285919)...
#  → Rows so far: 4500
# Fetching match 350 of 500 (match_id=8391285918)...
#  → Rows so far: 4510
# Fetching match 351 of 500 (match_id=8391285916)...
#  → Rows so far: 4520
# Fetching match 352 of 500 (match_id=8391285914)...
#  → Rows so far: 4530
# Fetching match 353 of 500 (match_id=8391285913)...
#  → Rows so far: 4540
# Fetching match 354 of 500 (match_id=8391285912)...
#  → Rows so far: 4550
# Fetching match 355 of 500 (match_id=8391285910)...
#  → Rows so far: 4560
# Fetching match 356 of 500 (match_id=8391285904)...
#  → Rows so far: 4570
# Fetching match 357 of 500 (match_id=8391285903)...
#  → Rows so far: 4580
# Fetching match 358 of 500 (match_id=8391285801)...
#  → Rows so far: 4590
# Fetching match 359 of 500 (match_id=8391285719)...
#  → Rows so far: 4600
# Fetching match 360 of 500 (match_id=8391285718)...
#  → Rows so far: 4610
# Fetching match 361 of 500 (match_id=8391285717)...
#  → Rows so far: 4620
# Fetching match 362 of 500 (match_id=8391285716)...
#  → Rows so far: 4630
# Fetching match 363 of 500 (match_id=8391285700)...
#  → Rows so far: 4640
# Fetching match 364 of 500 (match_id=8391285611)...
#  → Rows so far: 4650
# Fetching match 365 of 500 (match_id=8391285607)...
#  → Rows so far: 4660
# Fetching match 366 of 500 (match_id=8391285605)...
#  → Rows so far: 4670
# Fetching match 367 of 500 (match_id=8391285518)...
#  → Rows so far: 4680
# Fetching match 368 of 500 (match_id=8391285406)...
#  → Rows so far: 4690
# Fetching match 369 of 500 (match_id=8391285401)...
#  → Rows so far: 4700
# Fetching match 370 of 500 (match_id=8391285400)...
#  → Rows so far: 4710
# Fetching match 371 of 500 (match_id=8391285315)...
#  → Rows so far: 4720
# Fetching match 372 of 500 (match_id=8391285313)...
#  → Rows so far: 4730
# Fetching match 373 of 500 (match_id=8391285309)...
#  → Rows so far: 4740
# Fetching match 374 of 500 (match_id=8391285305)...
#  → Rows so far: 4750
# Fetching match 375 of 500 (match_id=8391285304)...
#  → Rows so far: 4760
# Fetching match 376 of 500 (match_id=8391285217)...
#  → Rows so far: 4770
# Fetching match 377 of 500 (match_id=8391285216)...
#  → Rows so far: 4780
# Fetching match 378 of 500 (match_id=8391285201)...
#  → Rows so far: 4790
# Fetching match 379 of 500 (match_id=8391285200)...
#  → Rows so far: 4800
# Fetching match 380 of 500 (match_id=8391285119)...
#  → Rows so far: 4810
# Fetching match 381 of 500 (match_id=8391285101)...
#  → Rows so far: 4820
# Fetching match 382 of 500 (match_id=8391285007)...
#  → Rows so far: 4830
# Fetching match 383 of 500 (match_id=8391285006)...
#  → Rows so far: 4840
# Fetching match 384 of 500 (match_id=8391284914)...
#  → Rows so far: 4850
# Fetching match 385 of 500 (match_id=8391284913)...
#  → Rows so far: 4860
# Fetching match 386 of 500 (match_id=8391284912)...
#  → Rows so far: 4870
# Fetching match 387 of 500 (match_id=8391284819)...
#  → Rows so far: 4880
# Fetching match 388 of 500 (match_id=8391284818)...
#  → Rows so far: 4890
# Fetching match 389 of 500 (match_id=8391284815)...
#  → Rows so far: 4900
# Fetching match 390 of 500 (match_id=8391284814)...
#  → Rows so far: 4910
# Fetching match 391 of 500 (match_id=8391284800)...
#  → Rows so far: 4920
# Fetching match 392 of 500 (match_id=8391284706)...
#  → Rows so far: 4930
# Fetching match 393 of 500 (match_id=8391284705)...
#  → Rows so far: 4940
# Fetching match 394 of 500 (match_id=8391284514)...
#  → Rows so far: 4950
# Fetching match 395 of 500 (match_id=8391284512)...
#  → Rows so far: 4960
# Fetching match 396 of 500 (match_id=8391284511)...
#  → Rows so far: 4970
# Fetching match 397 of 500 (match_id=8391284413)...
#  → Rows so far: 4980
# Fetching match 398 of 500 (match_id=8391284411)...
#  → Rows so far: 4990
# Fetching match 399 of 500 (match_id=8391284409)...
#  → Rows so far: 5000
# Fetching match 400 of 500 (match_id=8391284406)...
#  → Rows so far: 5010
# Fetching match 401 of 500 (match_id=8391284400)...
#  → Rows so far: 5020
# Fetching match 402 of 500 (match_id=8391284318)...
#  → Rows so far: 5030
# Fetching match 403 of 500 (match_id=8391284306)...
#  → Rows so far: 5040
# Fetching match 404 of 500 (match_id=8391284215)...
#  → Rows so far: 5050
# Fetching match 405 of 500 (match_id=8391284212)...
#  → Rows so far: 5060
# Fetching match 406 of 500 (match_id=8391284110)...
#  → Rows so far: 5070
# Fetching match 407 of 500 (match_id=8391284108)...
#  → Rows so far: 5080
# Fetching match 408 of 500 (match_id=8391284106)...
#  → Rows so far: 5090
# Fetching match 409 of 500 (match_id=8391284101)...
#  → Rows so far: 5100
# Fetching match 410 of 500 (match_id=8391284014)...
#  → Rows so far: 5110
# Fetching match 411 of 500 (match_id=8391284013)...
#  → Rows so far: 5120
# Fetching match 412 of 500 (match_id=8391284009)...
#  → Rows so far: 5130
# Fetching match 413 of 500 (match_id=8391283913)...
#  → Rows so far: 5140
# Fetching match 414 of 500 (match_id=8391283912)...
#  → Rows so far: 5150
# Fetching match 415 of 500 (match_id=8391283910)...
#  → Rows so far: 5160
# Fetching match 416 of 500 (match_id=8391283814)...
#  → Rows so far: 5170
# Fetching match 417 of 500 (match_id=8391283716)...
#  → Rows so far: 5180
# Fetching match 418 of 500 (match_id=8391283709)...
#  → Rows so far: 5190
# Fetching match 419 of 500 (match_id=8391283706)...
#  → Rows so far: 5200
# Fetching match 420 of 500 (match_id=8391283618)...
#  → Rows so far: 5210
# Fetching match 421 of 500 (match_id=8391283616)...
#  → Rows so far: 5220
# Fetching match 422 of 500 (match_id=8391283612)...
#  → Rows so far: 5230
# Fetching match 423 of 500 (match_id=8391283610)...
#  → Rows so far: 5240
# Fetching match 424 of 500 (match_id=8391283609)...
#  → Rows so far: 5250
# Fetching match 425 of 500 (match_id=8391283607)...
#  → Rows so far: 5260
# Fetching match 426 of 500 (match_id=8391283605)...
#  → Rows so far: 5270
# Fetching match 427 of 500 (match_id=8391283604)...
#  → Rows so far: 5280
# Fetching match 428 of 500 (match_id=8391283603)...
#  → Rows so far: 5290
# Fetching match 429 of 500 (match_id=8391283602)...
#  → Rows so far: 5300
# Fetching match 430 of 500 (match_id=8391283510)...
#  → Rows so far: 5310
# Fetching match 431 of 500 (match_id=8391283509)...
#  → Rows so far: 5320
# Fetching match 432 of 500 (match_id=8391283506)...
#  → Rows so far: 5330
# Fetching match 433 of 500 (match_id=8391283503)...
#  → Rows so far: 5340
# Fetching match 434 of 500 (match_id=8391283502)...
#  → Rows so far: 5350
# Fetching match 435 of 500 (match_id=8391283419)...
#  → Rows so far: 5360
# Fetching match 436 of 500 (match_id=8391283415)...
#  → Rows so far: 5370
# Fetching match 437 of 500 (match_id=8391283414)...
#  → Rows so far: 5380
# Fetching match 438 of 500 (match_id=8391283317)...
#  → Rows so far: 5390
# Fetching match 439 of 500 (match_id=8391283216)...
#  → Rows so far: 5400
# Fetching match 440 of 500 (match_id=8391283211)...
#  → Rows so far: 5410
# Fetching match 441 of 500 (match_id=8391283210)...
#  → Rows so far: 5420
# Fetching match 442 of 500 (match_id=8391283208)...
#  → Rows so far: 5430
# Fetching match 443 of 500 (match_id=8391283207)...
#  → Rows so far: 5440
# Fetching match 444 of 500 (match_id=8391283103)...
#  → Rows so far: 5450
# Fetching match 445 of 500 (match_id=8391283102)...
#  → Rows so far: 5460
# Fetching match 446 of 500 (match_id=8391283100)...
#  → Rows so far: 5470
# Fetching match 447 of 500 (match_id=8391283018)...
#  → Rows so far: 5480
# Fetching match 448 of 500 (match_id=8391283017)...
#  → Rows so far: 5490
# Fetching match 449 of 500 (match_id=8391283015)...
#  → Rows so far: 5500
# Fetching match 450 of 500 (match_id=8391283012)...
#  → Rows so far: 5510
# Fetching match 451 of 500 (match_id=8391283010)...
#  → Rows so far: 5520
# Fetching match 452 of 500 (match_id=8391282917)...
#  → Rows so far: 5530
# Fetching match 453 of 500 (match_id=8391282900)...
#  → Rows so far: 5540
# Fetching match 454 of 500 (match_id=8391282818)...
#  → Rows so far: 5550
# Fetching match 455 of 500 (match_id=8391282816)...
#  → Rows so far: 5560
# Fetching match 456 of 500 (match_id=8391282815)...
#  → Rows so far: 5570
# Fetching match 457 of 500 (match_id=8391282814)...
#  → Rows so far: 5580
# Fetching match 458 of 500 (match_id=8391282801)...
#  → Rows so far: 5590
# Fetching match 459 of 500 (match_id=8391282800)...
#  → Rows so far: 5600
# Fetching match 460 of 500 (match_id=8391282709)...
#  → Rows so far: 5610
# Fetching match 461 of 500 (match_id=8391282704)...
#  → Rows so far: 5620
# Fetching match 462 of 500 (match_id=8391282701)...
#  → Rows so far: 5630
# Fetching match 463 of 500 (match_id=8391282700)...
#  → Rows so far: 5640
# Fetching match 464 of 500 (match_id=8391282618)...
#  → Rows so far: 5650
# Fetching match 465 of 500 (match_id=8391282609)...
#  → Rows so far: 5660
# Fetching match 466 of 500 (match_id=8391282608)...
#  → Rows so far: 5670
# Fetching match 467 of 500 (match_id=8391282607)...
#  → Rows so far: 5680
# Fetching match 468 of 500 (match_id=8391282601)...
#  → Rows so far: 5690
# Fetching match 469 of 500 (match_id=8391282519)...
#  → Rows so far: 5700
# Fetching match 470 of 500 (match_id=8391282517)...
#  → Rows so far: 5710
# Fetching match 471 of 500 (match_id=8391282509)...
#  → Rows so far: 5720
# Fetching match 472 of 500 (match_id=8391282507)...
#  → Rows so far: 5730
# Fetching match 473 of 500 (match_id=8391282417)...
#  → Rows so far: 5740
# Fetching match 474 of 500 (match_id=8391282415)...
#  → Rows so far: 5750
# Fetching match 475 of 500 (match_id=8391282414)...
#  → Rows so far: 5760
# Fetching match 476 of 500 (match_id=8391282412)...
#  → Rows so far: 5770
# Fetching match 477 of 500 (match_id=8391282410)...
#  → Rows so far: 5780
# Fetching match 478 of 500 (match_id=8391282407)...
#  → Rows so far: 5790
# Fetching match 479 of 500 (match_id=8391282406)...
#  → Rows so far: 5800
# Fetching match 480 of 500 (match_id=8391282405)...
#  → Rows so far: 5810
# Fetching match 481 of 500 (match_id=8391282315)...
#  → Rows so far: 5820
# Fetching match 482 of 500 (match_id=8391282314)...
#  → Rows so far: 5830
# Fetching match 483 of 500 (match_id=8391282312)...
#  → Rows so far: 5840
# Fetching match 484 of 500 (match_id=8391282309)...
#  → Rows so far: 5850
# Fetching match 485 of 500 (match_id=8391282209)...
#  → Rows so far: 5860
# Fetching match 486 of 500 (match_id=8391282208)...
#  → Rows so far: 5870
# Fetching match 487 of 500 (match_id=8391282204)...
#  → Rows so far: 5880
# Fetching match 488 of 500 (match_id=8391282203)...
#  → Rows so far: 5890
# Fetching match 489 of 500 (match_id=8391282202)...
#  → Rows so far: 5900
# Fetching match 490 of 500 (match_id=8391282118)...
#  → Rows so far: 5910
# Fetching match 491 of 500 (match_id=8391282117)...
#  → Rows so far: 5920
# Fetching match 492 of 500 (match_id=8391282114)...
#  → Rows so far: 5930
# Fetching match 493 of 500 (match_id=8391282018)...
#  → Rows so far: 5940
# Fetching match 494 of 500 (match_id=8391282017)...
#  → Rows so far: 5950
# Fetching match 495 of 500 (match_id=8391282014)...
#  → Rows so far: 5960
# Fetching match 496 of 500 (match_id=8391282004)...
#  → Rows so far: 5970
# Fetching match 497 of 500 (match_id=8391282003)...
#  → Rows so far: 5980
# Fetching match 498 of 500 (match_id=8391282002)...
#  → Rows so far: 5990
# Fetching match 499 of 500 (match_id=8391282001)...
#  → Rows so far: 6000
# Fetching match 500 of 500 (match_id=8391281912)...
#  → Rows so far: 6010
# Saved 6010 rows to C:\Users\Ellen\Desktop\OpenDota Data\match_details_500matches.csv
# Matches processed: 601 of 500

# %% [markdown]
# **Script re-run for remaining 499 player match data**

# %%
# --- File paths ---
matches_file = r"C:\Users\Ellen\Desktop\OpenDota Data\opendota_matches_500plus.csv"
output_file = r"C:\Users\Ellen\Desktop\OpenDota Data\match_details_500matches.csv"

# Base URL for OpenDota API
BASE_URL = "https://api.opendota.com/api"
MATCH_DETAIL_URL = f"{BASE_URL}/matches/{{match_id}}"

# --- Load match IDs ---
all_matches_df = pd.read_csv(matches_file)
match_ids = all_matches_df['match_id'].unique()[:1100]

# --- Load existing output (if available) ---
if os.path.exists(output_file):
    existing_df = pd.read_csv(output_file)
    processed_matches = set(existing_df['match_id'].unique())
    print(f"Resuming: {len(processed_matches)} matches already processed, {len(existing_df)} rows in file.")
else:
    existing_df = pd.DataFrame()
    processed_matches = set()
    print("No existing file found. Starting fresh.")

# --- Find remaining matches ---
remaining_match_ids = [mid for mid in match_ids if mid not in processed_matches]
print(f"\nPre-Check Summary:")
print(f" → Total match IDs available: {len(match_ids)}")
print(f" → Already processed: {len(processed_matches)} matches")
print(f" → Remaining to process: {len(remaining_match_ids)} matches\n")

def fetch_match_details(match_id):
    url = MATCH_DETAIL_URL.format(match_id=match_id)
    response = requests.get(url)
    if response.status_code == 429:  # Rate limit handling
        retry_after = int(response.headers.get('Retry-After', 60))
        print(f"Rate limit hit. Waiting {retry_after} seconds...")
        time.sleep(retry_after)
        response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching match {match_id}: {response.status_code}")
        return None

# --- Fetch matches ---
all_new_data = []
total_rows = len(existing_df)

for i, match_id in enumerate(remaining_match_ids, start=1):
    print(f"Fetching match {i} of {len(remaining_match_ids)} (match_id={match_id})...")
    match_data = fetch_match_details(match_id)
    if match_data:
        player_rows = []
        for player in match_data.get("players", []):
            player_rows.append({
                "match_id": match_id,
                "account_id": player.get("account_id"),
                "hero_id": player.get("hero_id"),
                "kills": player.get("kills"),
                "deaths": player.get("deaths"),
                "assists": player.get("assists"),
                "gold_per_min": player.get("gold_per_min"),
                "xp_per_min": player.get("xp_per_min"),
                "hero_damage": player.get("hero_damage"),
                "hero_healing": player.get("hero_healing"),
                "duration": match_data.get("duration"),
                "radiant_win": match_data.get("radiant_win"),
                "start_time": match_data.get("start_time")
            })
        all_new_data.extend(player_rows)
        total_rows += len(player_rows)
        print(f" → Rows so far: {total_rows}")
    time.sleep(1)

# --- Combine old + new data ---
if len(existing_df) > 0:
    final_df = pd.concat([existing_df, pd.DataFrame(all_new_data)], ignore_index=True)
else:
    final_df = pd.DataFrame(all_new_data)

# --- Save file ---
final_df.to_csv(output_file, index=False)
print(f"\nSaved {len(final_df)} rows to {output_file}")
print(f"Matches processed: {len(final_df['match_id'].unique())} of {len(match_ids)}")
# Out:
# Resuming: 601 matches already processed, 6010 rows in file.
#
# Pre-Check Summary:
#  → Total match IDs available: 1100
#  → Already processed: 601 matches
#  → Remaining to process: 600 matches
#
# Fetching match 1 of 600 (match_id=8391281904)...
#  → Rows so far: 6020
# Fetching match 2 of 600 (match_id=8391281902)...
#  → Rows so far: 6030
# Fetching match 3 of 600 (match_id=8391281900)...
#  → Rows so far: 6040
# Fetching match 4 of 600 (match_id=8391281816)...
#  → Rows so far: 6050
# Fetching match 5 of 600 (match_id=8391281813)...
#  → Rows so far: 6060
# Fetching match 6 of 600 (match_id=8391281812)...
#  → Rows so far: 6070
# Fetching match 7 of 600 (match_id=8391281810)...
#  → Rows so far: 6080
# Fetching match 8 of 600 (match_id=8391281809)...
#  → Rows so far: 6090
# Fetching match 9 of 600 (match_id=8391281808)...
#  → Rows so far: 6100
# Fetching match 10 of 600 (match_id=8391281803)...
#  → Rows so far: 6110
# Fetching match 11 of 600 (match_id=8391281706)...
#  → Rows so far: 6120
# Fetching match 12 of 600 (match_id=8391281701)...
#  → Rows so far: 6130
# Fetching match 13 of 600 (match_id=8391281614)...
#  → Rows so far: 6140
# Fetching match 14 of 600 (match_id=8391281609)...
#  → Rows so far: 6150
# Fetching match 15 of 600 (match_id=8391281607)...
#  → Rows so far: 6160
# Fetching match 16 of 600 (match_id=8391281512)...
#  → Rows so far: 6170
# Fetching match 17 of 600 (match_id=8391281409)...
#  → Rows so far: 6180
# Fetching match 18 of 600 (match_id=8391281408)...
#  → Rows so far: 6190
# Fetching match 19 of 600 (match_id=8391281407)...
#  → Rows so far: 6200
# Fetching match 20 of 600 (match_id=8391281316)...
#  → Rows so far: 6210
# Fetching match 21 of 600 (match_id=8391281315)...
#  → Rows so far: 6220
# Fetching match 22 of 600 (match_id=8391281313)...
#  → Rows so far: 6230
# Fetching match 23 of 600 (match_id=8391281306)...
#  → Rows so far: 6240
# Fetching match 24 of 600 (match_id=8391281300)...
#  → Rows so far: 6250
# Fetching match 25 of 600 (match_id=8391281213)...
#  → Rows so far: 6260
# Fetching match 26 of 600 (match_id=8391281205)...
#  → Rows so far: 6270
# Fetching match 27 of 600 (match_id=8391281202)...
#  → Rows so far: 6280
# Fetching match 28 of 600 (match_id=8391281112)...
#  → Rows so far: 6290
# Fetching match 29 of 600 (match_id=8391281111)...
#  → Rows so far: 6300
# Fetching match 30 of 600 (match_id=8391281018)...
#  → Rows so far: 6310
# Fetching match 31 of 600 (match_id=8391281012)...
#  → Rows so far: 6320
# Fetching match 32 of 600 (match_id=8391281002)...
#  → Rows so far: 6330
# Fetching match 33 of 600 (match_id=8391281001)...
#  → Rows so far: 6340
# Fetching match 34 of 600 (match_id=8391280918)...
#  → Rows so far: 6350
# Fetching match 35 of 600 (match_id=8391280917)...
#  → Rows so far: 6360
# Fetching match 36 of 600 (match_id=8391280915)...
#  → Rows so far: 6370
# Fetching match 37 of 600 (match_id=8391280913)...
#  → Rows so far: 6380
# Fetching match 38 of 600 (match_id=8391280912)...
#  → Rows so far: 6390
# Fetching match 39 of 600 (match_id=8391280910)...
#  → Rows so far: 6400
# Fetching match 40 of 600 (match_id=8391280813)...
#  → Rows so far: 6410
# Fetching match 41 of 600 (match_id=8391280807)...
#  → Rows so far: 6420
# Fetching match 42 of 600 (match_id=8391280806)...
#  → Rows so far: 6430
# Fetching match 43 of 600 (match_id=8391280804)...
#  → Rows so far: 6440
# Fetching match 44 of 600 (match_id=8391280714)...
#  → Rows so far: 6450
# Fetching match 45 of 600 (match_id=8391280712)...
#  → Rows so far: 6460
# Fetching match 46 of 600 (match_id=8391280710)...
#  → Rows so far: 6470
# Fetching match 47 of 600 (match_id=8391280606)...
#  → Rows so far: 6480
# Fetching match 48 of 600 (match_id=8391280511)...
#  → Rows so far: 6490
# Fetching match 49 of 600 (match_id=8391280508)...
#  → Rows so far: 6500
# Fetching match 50 of 600 (match_id=8391280503)...
#  → Rows so far: 6510
# Fetching match 51 of 600 (match_id=8391280501)...
#  → Rows so far: 6520
# Fetching match 52 of 600 (match_id=8391280417)...
#  → Rows so far: 6530
# Fetching match 53 of 600 (match_id=8391280412)...
#  → Rows so far: 6540
# Fetching match 54 of 600 (match_id=8391280411)...
#  → Rows so far: 6550
# Fetching match 55 of 600 (match_id=8391280407)...
#  → Rows so far: 6560
# Fetching match 56 of 600 (match_id=8391280315)...
#  → Rows so far: 6570
# Fetching match 57 of 600 (match_id=8391280311)...
#  → Rows so far: 6580
# Fetching match 58 of 600 (match_id=8391280310)...
#  → Rows so far: 6590
# Fetching match 59 of 600 (match_id=8391280309)...
#  → Rows so far: 6600
# Fetching match 60 of 600 (match_id=8391280306)...
#  → Rows so far: 6610
# Fetching match 61 of 600 (match_id=8391280206)...
#  → Rows so far: 6620
# Fetching match 62 of 600 (match_id=8391280204)...
#  → Rows so far: 6630
# Fetching match 63 of 600 (match_id=8391280116)...
#  → Rows so far: 6640
# Fetching match 64 of 600 (match_id=8391280114)...
#  → Rows so far: 6650
# Fetching match 65 of 600 (match_id=8391280113)...
#  → Rows so far: 6660
# Fetching match 66 of 600 (match_id=8391280112)...
#  → Rows so far: 6670
# Fetching match 67 of 600 (match_id=8391280111)...
#  → Rows so far: 6680
# Fetching match 68 of 600 (match_id=8391280011)...
#  → Rows so far: 6690
# Fetching match 69 of 600 (match_id=8391280010)...
#  → Rows so far: 6700
# Fetching match 70 of 600 (match_id=8391280006)...
#  → Rows so far: 6710
# Fetching match 71 of 600 (match_id=8391280005)...
#  → Rows so far: 6720
# Fetching match 72 of 600 (match_id=8391279919)...
#  → Rows so far: 6730
# Fetching match 73 of 600 (match_id=8391279916)...
#  → Rows so far: 6740
# Fetching match 74 of 600 (match_id=8391279817)...
#  → Rows so far: 6750
# Fetching match 75 of 600 (match_id=8391279814)...
#  → Rows so far: 6760
# Fetching match 76 of 600 (match_id=8391279805)...
#  → Rows so far: 6770
# Fetching match 77 of 600 (match_id=8391279804)...
#  → Rows so far: 6780
# Fetching match 78 of 600 (match_id=8391279801)...
#  → Rows so far: 6790
# Fetching match 79 of 600 (match_id=8391279716)...
#  → Rows so far: 6800
# Fetching match 80 of 600 (match_id=8391279715)...
#  → Rows so far: 6810
# Fetching match 81 of 600 (match_id=8391279703)...
#  → Rows so far: 6820
# Fetching match 82 of 600 (match_id=8391279702)...
#  → Rows so far: 6830
# Fetching match 83 of 600 (match_id=8391279617)...
#  → Rows so far: 6840
# Fetching match 84 of 600 (match_id=8391279615)...
#  → Rows so far: 6850
# Fetching match 85 of 600 (match_id=8391279518)...
#  → Rows so far: 6860
# Fetching match 86 of 600 (match_id=8391279517)...
#  → Rows so far: 6870
# Fetching match 87 of 600 (match_id=8391279513)...
#  → Rows so far: 6880
# Fetching match 88 of 600 (match_id=8391279511)...
#  → Rows so far: 6890
# Fetching match 89 of 600 (match_id=8391279509)...
#  → Rows so far: 6900
# Fetching match 90 of 600 (match_id=8391279508)...
#  → Rows so far: 6910
# Fetching match 91 of 600 (match_id=8391279417)...
#  → Rows so far: 6920
# Fetching match 92 of 600 (match_id=8391279311)...
#  → Rows so far: 6930
# Fetching match 93 of 600 (match_id=8391279309)...
#  → Rows so far: 6940
# Fetching match 94 of 600 (match_id=8391279308)...
#  → Rows so far: 6950
# Fetching match 95 of 600 (match_id=8391279307)...
#  → Rows so far: 6960
# Fetching match 96 of 600 (match_id=8391279305)...
#  → Rows so far: 6970
# Fetching match 97 of 600 (match_id=8391279303)...
#  → Rows so far: 6980
# Fetching match 98 of 600 (match_id=8391279302)...
#  → Rows so far: 6990
# Fetching match 99 of 600 (match_id=8391279301)...
#  → Rows so far: 7000
# Fetching match 100 of 600 (match_id=8391279300)...
#  → Rows so far: 7010
# Fetching match 101 of 600 (match_id=8391279216)...
#  → Rows so far: 7020
# Fetching match 102 of 600 (match_id=8391279215)...
#  → Rows so far: 7030
# Fetching match 103 of 600 (match_id=8391279214)...
#  → Rows so far: 7040
# Fetching match 104 of 600 (match_id=8391279210)...
#  → Rows so far: 7050
# Fetching match 105 of 600 (match_id=8391279208)...
#  → Rows so far: 7060
# Fetching match 106 of 600 (match_id=8391279207)...
#  → Rows so far: 7070
# Fetching match 107 of 600 (match_id=8391279201)...
#  → Rows so far: 7080
# Fetching match 108 of 600 (match_id=8391279118)...
#  → Rows so far: 7090
# Fetching match 109 of 600 (match_id=8391279116)...
#  → Rows so far: 7100
# Fetching match 110 of 600 (match_id=8391279018)...
#  → Rows so far: 7110
# Fetching match 111 of 600 (match_id=8391279014)...
#  → Rows so far: 7120
# Fetching match 112 of 600 (match_id=8391279013)...
#  → Rows so far: 7130
# Fetching match 113 of 600 (match_id=8391279001)...
#  → Rows so far: 7140
# Fetching match 114 of 600 (match_id=8391279000)...
#  → Rows so far: 7150
# Fetching match 115 of 600 (match_id=8391278919)...
#  → Rows so far: 7160
# Fetching match 116 of 600 (match_id=8391278918)...
#  → Rows so far: 7170
# Fetching match 117 of 600 (match_id=8391278916)...
#  → Rows so far: 7180
# Fetching match 118 of 600 (match_id=8391278909)...
#  → Rows so far: 7190
# Fetching match 119 of 600 (match_id=8391278905)...
#  → Rows so far: 7200
# Fetching match 120 of 600 (match_id=8391278904)...
#  → Rows so far: 7210
# Fetching match 121 of 600 (match_id=8391278902)...
#  → Rows so far: 7220
# Fetching match 122 of 600 (match_id=8391278900)...
#  → Rows so far: 7230
# Fetching match 123 of 600 (match_id=8391278808)...
#  → Rows so far: 7240
# Fetching match 124 of 600 (match_id=8391278806)...
#  → Rows so far: 7250
# Fetching match 125 of 600 (match_id=8391278805)...
#  → Rows so far: 7260
# Fetching match 126 of 600 (match_id=8391278803)...
#  → Rows so far: 7270
# Fetching match 127 of 600 (match_id=8391278718)...
#  → Rows so far: 7280
# Fetching match 128 of 600 (match_id=8391278713)...
#  → Rows so far: 7290
# Fetching match 129 of 600 (match_id=8391278708)...
#  → Rows so far: 7300
# Fetching match 130 of 600 (match_id=8391278618)...
#  → Rows so far: 7310
# Fetching match 131 of 600 (match_id=8391278607)...
#  → Rows so far: 7320
# Fetching match 132 of 600 (match_id=8391278606)...
#  → Rows so far: 7330
# Fetching match 133 of 600 (match_id=8391278602)...
#  → Rows so far: 7340
# Fetching match 134 of 600 (match_id=8391278601)...
#  → Rows so far: 7350
# Fetching match 135 of 600 (match_id=8391278509)...
#  → Rows so far: 7360
# Fetching match 136 of 600 (match_id=8391278508)...
#  → Rows so far: 7370
# Fetching match 137 of 600 (match_id=8391278505)...
#  → Rows so far: 7380
# Fetching match 138 of 600 (match_id=8391278500)...
#  → Rows so far: 7390
# Fetching match 139 of 600 (match_id=8391278418)...
#  → Rows so far: 7400
# Fetching match 140 of 600 (match_id=8391278417)...
#  → Rows so far: 7410
# Fetching match 141 of 600 (match_id=8391278415)...
#  → Rows so far: 7420
# Fetching match 142 of 600 (match_id=8391278414)...
#  → Rows so far: 7430
# Fetching match 143 of 600 (match_id=8391278413)...
#  → Rows so far: 7440
# Fetching match 144 of 600 (match_id=8391278319)...
#  → Rows so far: 7450
# Fetching match 145 of 600 (match_id=8391278309)...
#  → Rows so far: 7460
# Fetching match 146 of 600 (match_id=8391278306)...
#  → Rows so far: 7470
# Fetching match 147 of 600 (match_id=8391278219)...
#  → Rows so far: 7480
# Fetching match 148 of 600 (match_id=8391278217)...
#  → Rows so far: 7490
# Fetching match 149 of 600 (match_id=8391278216)...
#  → Rows so far: 7500
# Fetching match 150 of 600 (match_id=8391278203)...
#  → Rows so far: 7510
# Fetching match 151 of 600 (match_id=8391278201)...
#  → Rows so far: 7520
# Fetching match 152 of 600 (match_id=8391278200)...
#  → Rows so far: 7530
# Fetching match 153 of 600 (match_id=8391278112)...
#  → Rows so far: 7540
# Fetching match 154 of 600 (match_id=8391278018)...
#  → Rows so far: 7550
# Fetching match 155 of 600 (match_id=8391278015)...
#  → Rows so far: 7560
# Fetching match 156 of 600 (match_id=8391278014)...
#  → Rows so far: 7570
# Fetching match 157 of 600 (match_id=8391278013)...
#  → Rows so far: 7580
# Fetching match 158 of 600 (match_id=8391278000)...
#  → Rows so far: 7590
# Fetching match 159 of 600 (match_id=8391277918)...
#  → Rows so far: 7600
# Fetching match 160 of 600 (match_id=8391277902)...
#  → Rows so far: 7610
# Fetching match 161 of 600 (match_id=8391277817)...
#  → Rows so far: 7620
# Fetching match 162 of 600 (match_id=8391277816)...
#  → Rows so far: 7630
# Fetching match 163 of 600 (match_id=8391277813)...
#  → Rows so far: 7640
# Fetching match 164 of 600 (match_id=8391277800)...
#  → Rows so far: 7650
# Fetching match 165 of 600 (match_id=8391277707)...
#  → Rows so far: 7660
# Fetching match 166 of 600 (match_id=8391277706)...
#  → Rows so far: 7670
# Fetching match 167 of 600 (match_id=8391277705)...
#  → Rows so far: 7680
# Fetching match 168 of 600 (match_id=8391277704)...
#  → Rows so far: 7690
# Fetching match 169 of 600 (match_id=8391277617)...
#  → Rows so far: 7700
# Fetching match 170 of 600 (match_id=8391277607)...
#  → Rows so far: 7710
# Fetching match 171 of 600 (match_id=8391277606)...
#  → Rows so far: 7720
# Fetching match 172 of 600 (match_id=8391277605)...
#  → Rows so far: 7730
# Fetching match 173 of 600 (match_id=8391277604)...
#  → Rows so far: 7740
# Fetching match 174 of 600 (match_id=8391277603)...
#  → Rows so far: 7750
# Fetching match 175 of 600 (match_id=8391277518)...
#  → Rows so far: 7760
# Fetching match 176 of 600 (match_id=8391277508)...
#  → Rows so far: 7770
# Fetching match 177 of 600 (match_id=8391277506)...
#  → Rows so far: 7780
# Fetching match 178 of 600 (match_id=8391277505)...
#  → Rows so far: 7790
# Fetching match 179 of 600 (match_id=8391277504)...
#  → Rows so far: 7800
# Fetching match 180 of 600 (match_id=8391277503)...
#  → Rows so far: 7810
# Fetching match 181 of 600 (match_id=8391277501)...
#  → Rows so far: 7820
# Fetching match 182 of 600 (match_id=8391277419)...
#  → Rows so far: 7830
# Fetching match 183 of 600 (match_id=8391277418)...
#  → Rows so far: 7840
# Fetching match 184 of 600 (match_id=8391277406)...
#  → Rows so far: 7850
# Fetching match 185 of 600 (match_id=8391277405)...
#  → Rows so far: 7860
# Fetching match 186 of 600 (match_id=8391277404)...
#  → Rows so far: 7870
# Fetching match 187 of 600 (match_id=8391277319)...
#  → Rows so far: 7880
# Fetching match 188 of 600 (match_id=8391277306)...
#  → Rows so far: 7890
# Fetching match 189 of 600 (match_id=8391277305)...
#  → Rows so far: 7900
# Fetching match 190 of 600 (match_id=8391277303)...
#  → Rows so far: 7910
# Fetching match 191 of 600 (match_id=8391277301)...
#  → Rows so far: 7920
# Fetching match 192 of 600 (match_id=8391277300)...
#  → Rows so far: 7930
# Fetching match 193 of 600 (match_id=8391277216)...
#  → Rows so far: 7940
# Fetching match 194 of 600 (match_id=8391277215)...
#  → Rows so far: 7950
# Fetching match 195 of 600 (match_id=8391277214)...
#  → Rows so far: 7960
# Fetching match 196 of 600 (match_id=8391277212)...
#  → Rows so far: 7970
# Fetching match 197 of 600 (match_id=8391277211)...
#  → Rows so far: 7980
# Fetching match 198 of 600 (match_id=8391277210)...
#  → Rows so far: 7990
# Fetching match 199 of 600 (match_id=8391277117)...
#  → Rows so far: 8000
# Fetching match 200 of 600 (match_id=8391277114)...
#  → Rows so far: 8010
# Fetching match 201 of 600 (match_id=8391277113)...
#  → Rows so far: 8020
# Fetching match 202 of 600 (match_id=8391277110)...
#  → Rows so far: 8030
# Fetching match 203 of 600 (match_id=8391277109)...
#  → Rows so far: 8040
# Fetching match 204 of 600 (match_id=8391277010)...
#  → Rows so far: 8050
# Fetching match 205 of 600 (match_id=8391277009)...
#  → Rows so far: 8060
# Fetching match 206 of 600 (match_id=8391277007)...
#  → Rows so far: 8070
# Fetching match 207 of 600 (match_id=8391277005)...
#  → Rows so far: 8080
# Fetching match 208 of 600 (match_id=8391277004)...
#  → Rows so far: 8090
# Fetching match 209 of 600 (match_id=8391277002)...
#  → Rows so far: 8100
# Fetching match 210 of 600 (match_id=8391277000)...
#  → Rows so far: 8110
# Fetching match 211 of 600 (match_id=8391276908)...
#  → Rows so far: 8120
# Fetching match 212 of 600 (match_id=8391276907)...
#  → Rows so far: 8130
# Fetching match 213 of 600 (match_id=8391276905)...
#  → Rows so far: 8140
# Fetching match 214 of 600 (match_id=8391276904)...
#  → Rows so far: 8150
# Fetching match 215 of 600 (match_id=8391276902)...
#  → Rows so far: 8160
# Fetching match 216 of 600 (match_id=8391276901)...
#  → Rows so far: 8170
# Fetching match 217 of 600 (match_id=8391276808)...
#  → Rows so far: 8180
# Fetching match 218 of 600 (match_id=8391276807)...
#  → Rows so far: 8190
# Fetching match 219 of 600 (match_id=8391276805)...
#  → Rows so far: 8200
# Fetching match 220 of 600 (match_id=8391276804)...
#  → Rows so far: 8210
# Fetching match 221 of 600 (match_id=8391276803)...
#  → Rows so far: 8220
# Fetching match 222 of 600 (match_id=8391276800)...
#  → Rows so far: 8230
# Fetching match 223 of 600 (match_id=8391276716)...
#  → Rows so far: 8240
# Fetching match 224 of 600 (match_id=8391276715)...
#  → Rows so far: 8250
# Fetching match 225 of 600 (match_id=8391276713)...
#  → Rows so far: 8260
# Fetching match 226 of 600 (match_id=8391276710)...
#  → Rows so far: 8270
# Fetching match 227 of 600 (match_id=8391276619)...
#  → Rows so far: 8280
# Fetching match 228 of 600 (match_id=8391276613)...
#  → Rows so far: 8290
# Fetching match 229 of 600 (match_id=8391276611)...
#  → Rows so far: 8300
# Fetching match 230 of 600 (match_id=8391276601)...
#  → Rows so far: 8310
# Fetching match 231 of 600 (match_id=8391276518)...
#  → Rows so far: 8320
# Fetching match 232 of 600 (match_id=8391276515)...
#  → Rows so far: 8330
# Fetching match 233 of 600 (match_id=8391276505)...
#  → Rows so far: 8340
# Fetching match 234 of 600 (match_id=8391276504)...
#  → Rows so far: 8350
# Fetching match 235 of 600 (match_id=8391276503)...
#  → Rows so far: 8360
# Fetching match 236 of 600 (match_id=8391276500)...
#  → Rows so far: 8370
# Fetching match 237 of 600 (match_id=8391276412)...
#  → Rows so far: 8380
# Fetching match 238 of 600 (match_id=8391276405)...
#  → Rows so far: 8390
# Fetching match 239 of 600 (match_id=8391276318)...
#  → Rows so far: 8400
# Fetching match 240 of 600 (match_id=8391276316)...
#  → Rows so far: 8410
# Fetching match 241 of 600 (match_id=8391276311)...
#  → Rows so far: 8420
# Fetching match 242 of 600 (match_id=8391276300)...
#  → Rows so far: 8430
# Fetching match 243 of 600 (match_id=8391276215)...
#  → Rows so far: 8440
# Fetching match 244 of 600 (match_id=8391276210)...
#  → Rows so far: 8450
# Fetching match 245 of 600 (match_id=8391276208)...
#  → Rows so far: 8460
# Fetching match 246 of 600 (match_id=8391276203)...
#  → Rows so far: 8470
# Fetching match 247 of 600 (match_id=8391276117)...
#  → Rows so far: 8480
# Fetching match 248 of 600 (match_id=8391276116)...
#  → Rows so far: 8490
# Fetching match 249 of 600 (match_id=8391276115)...
#  → Rows so far: 8500
# Fetching match 250 of 600 (match_id=8391276109)...
#  → Rows so far: 8510
# Fetching match 251 of 600 (match_id=8391276018)...
#  → Rows so far: 8520
# Fetching match 252 of 600 (match_id=8391276006)...
#  → Rows so far: 8530
# Fetching match 253 of 600 (match_id=8391276005)...
#  → Rows so far: 8540
# Fetching match 254 of 600 (match_id=8391276002)...
#  → Rows so far: 8550
# Fetching match 255 of 600 (match_id=8391276000)...
#  → Rows so far: 8560
# Fetching match 256 of 600 (match_id=8391275909)...
#  → Rows so far: 8570
# Fetching match 257 of 600 (match_id=8391275905)...
#  → Rows so far: 8580
# Fetching match 258 of 600 (match_id=8391275903)...
#  → Rows so far: 8590
# Fetching match 259 of 600 (match_id=8391275901)...
#  → Rows so far: 8600
# Fetching match 260 of 600 (match_id=8391275808)...
#  → Rows so far: 8610
# Fetching match 261 of 600 (match_id=8391275806)...
#  → Rows so far: 8620
# Fetching match 262 of 600 (match_id=8391275805)...
#  → Rows so far: 8630
# Fetching match 263 of 600 (match_id=8391275804)...
#  → Rows so far: 8640
# Fetching match 264 of 600 (match_id=8391275802)...
#  → Rows so far: 8650
# Fetching match 265 of 600 (match_id=8391275712)...
#  → Rows so far: 8660
# Fetching match 266 of 600 (match_id=8391275711)...
#  → Rows so far: 8670
# Fetching match 267 of 600 (match_id=8391275710)...
#  → Rows so far: 8680
# Fetching match 268 of 600 (match_id=8391275708)...
#  → Rows so far: 8690
# Fetching match 269 of 600 (match_id=8391275702)...
#  → Rows so far: 8700
# Fetching match 270 of 600 (match_id=8391275701)...
#  → Rows so far: 8710
# Fetching match 271 of 600 (match_id=8391275700)...
#  → Rows so far: 8720
# Fetching match 272 of 600 (match_id=8391275619)...
#  → Rows so far: 8730
# Fetching match 273 of 600 (match_id=8391275617)...
#  → Rows so far: 8740
# Fetching match 274 of 600 (match_id=8391275616)...
#  → Rows so far: 8750
# Fetching match 275 of 600 (match_id=8391275615)...
#  → Rows so far: 8760
# Fetching match 276 of 600 (match_id=8391275610)...
#  → Rows so far: 8770
# Fetching match 277 of 600 (match_id=8391275519)...
#  → Rows so far: 8780
# Fetching match 278 of 600 (match_id=8391275502)...
#  → Rows so far: 8790
# Fetching match 279 of 600 (match_id=8391275413)...
#  → Rows so far: 8800
# Fetching match 280 of 600 (match_id=8391275404)...
#  → Rows so far: 8810
# Fetching match 281 of 600 (match_id=8391275403)...
#  → Rows so far: 8820
# Fetching match 282 of 600 (match_id=8391275402)...
#  → Rows so far: 8830
# Fetching match 283 of 600 (match_id=8391275401)...
#  → Rows so far: 8840
# Fetching match 284 of 600 (match_id=8391275319)...
#  → Rows so far: 8850
# Fetching match 285 of 600 (match_id=8391275315)...
#  → Rows so far: 8860
# Fetching match 286 of 600 (match_id=8391275314)...
#  → Rows so far: 8870
# Fetching match 287 of 600 (match_id=8391275309)...
#  → Rows so far: 8880
# Fetching match 288 of 600 (match_id=8391275213)...
#  → Rows so far: 8890
# Fetching match 289 of 600 (match_id=8391275212)...
#  → Rows so far: 8900
# Fetching match 290 of 600 (match_id=8391275210)...
#  → Rows so far: 8910
# Fetching match 291 of 600 (match_id=8391275208)...
#  → Rows so far: 8920
# Fetching match 292 of 600 (match_id=8391275203)...
#  → Rows so far: 8930
# Fetching match 293 of 600 (match_id=8391275202)...
#  → Rows so far: 8940
# Fetching match 294 of 600 (match_id=8391275102)...
#  → Rows so far: 8950
# Fetching match 295 of 600 (match_id=8391275101)...
#  → Rows so far: 8960
# Fetching match 296 of 600 (match_id=8391275015)...
#  → Rows so far: 8970
# Fetching match 297 of 600 (match_id=8391275013)...
#  → Rows so far: 8980
# Fetching match 298 of 600 (match_id=8391275010)...
#  → Rows so far: 8990
# Fetching match 299 of 600 (match_id=8391275002)...
#  → Rows so far: 9000
# Fetching match 300 of 600 (match_id=8391275001)...
#  → Rows so far: 9010
# Fetching match 301 of 600 (match_id=8391275000)...
#  → Rows so far: 9020
# Fetching match 302 of 600 (match_id=8391274905)...
#  → Rows so far: 9030
# Fetching match 303 of 600 (match_id=8391274904)...
#  → Rows so far: 9040
# Fetching match 304 of 600 (match_id=8391274902)...
#  → Rows so far: 9050
# Fetching match 305 of 600 (match_id=8391274901)...
#  → Rows so far: 9060
# Fetching match 306 of 600 (match_id=8391274805)...
#  → Rows so far: 9070
# Fetching match 307 of 600 (match_id=8391274803)...
#  → Rows so far: 9080
# Fetching match 308 of 600 (match_id=8391274800)...
#  → Rows so far: 9090
# Fetching match 309 of 600 (match_id=8391274709)...
#  → Rows so far: 9100
# Fetching match 310 of 600 (match_id=8391274708)...
#  → Rows so far: 9110
# Fetching match 311 of 600 (match_id=8391274706)...
#  → Rows so far: 9120
# Fetching match 312 of 600 (match_id=8391274704)...
#  → Rows so far: 9130
# Fetching match 313 of 600 (match_id=8391274611)...
#  → Rows so far: 9140
# Fetching match 314 of 600 (match_id=8391274609)...
#  → Rows so far: 9150
# Fetching match 315 of 600 (match_id=8391274607)...
#  → Rows so far: 9160
# Fetching match 316 of 600 (match_id=8391274508)...
#  → Rows so far: 9170
# Fetching match 317 of 600 (match_id=8391274506)...
#  → Rows so far: 9180
# Fetching match 318 of 600 (match_id=8391274505)...
#  → Rows so far: 9190
# Fetching match 319 of 600 (match_id=8391274500)...
#  → Rows so far: 9200
# Fetching match 320 of 600 (match_id=8391274418)...
#  → Rows so far: 9210
# Fetching match 321 of 600 (match_id=8391274411)...
#  → Rows so far: 9220
# Fetching match 322 of 600 (match_id=8391274408)...
#  → Rows so far: 9230
# Fetching match 323 of 600 (match_id=8391274407)...
#  → Rows so far: 9240
# Fetching match 324 of 600 (match_id=8391274406)...
#  → Rows so far: 9250
# Fetching match 325 of 600 (match_id=8391274404)...
#  → Rows so far: 9260
# Fetching match 326 of 600 (match_id=8391274319)...
#  → Rows so far: 9270
# Fetching match 327 of 600 (match_id=8391274318)...
#  → Rows so far: 9280
# Fetching match 328 of 600 (match_id=8391274315)...
#  → Rows so far: 9290
# Fetching match 329 of 600 (match_id=8391274314)...
#  → Rows so far: 9300
# Fetching match 330 of 600 (match_id=8391274312)...
#  → Rows so far: 9310
# Fetching match 331 of 600 (match_id=8391274304)...
#  → Rows so far: 9320
# Fetching match 332 of 600 (match_id=8391274302)...
#  → Rows so far: 9330
# Fetching match 333 of 600 (match_id=8391274219)...
#  → Rows so far: 9340
# Fetching match 334 of 600 (match_id=8391274216)...
#  → Rows so far: 9350
# Fetching match 335 of 600 (match_id=8391274213)...
#  → Rows so far: 9360
# Fetching match 336 of 600 (match_id=8391274204)...
#  → Rows so far: 9370
# Fetching match 337 of 600 (match_id=8391274202)...
#  → Rows so far: 9380
# Fetching match 338 of 600 (match_id=8391274201)...
#  → Rows so far: 9390
# Fetching match 339 of 600 (match_id=8391274115)...
#  → Rows so far: 9400
# Fetching match 340 of 600 (match_id=8391274112)...
#  → Rows so far: 9410
# Fetching match 341 of 600 (match_id=8391274111)...
#  → Rows so far: 9420
# Fetching match 342 of 600 (match_id=8391274017)...
#  → Rows so far: 9430
# Fetching match 343 of 600 (match_id=8391274015)...
#  → Rows so far: 9440
# Fetching match 344 of 600 (match_id=8391274013)...
#  → Rows so far: 9450
# Fetching match 345 of 600 (match_id=8391274002)...
#  → Rows so far: 9460
# Fetching match 346 of 600 (match_id=8391273912)...
#  → Rows so far: 9470
# Fetching match 347 of 600 (match_id=8391273911)...
#  → Rows so far: 9480
# Fetching match 348 of 600 (match_id=8391273910)...
#  → Rows so far: 9490
# Fetching match 349 of 600 (match_id=8391273909)...
#  → Rows so far: 9500
# Fetching match 350 of 600 (match_id=8391273907)...
#  → Rows so far: 9510
# Fetching match 351 of 600 (match_id=8391273906)...
#  → Rows so far: 9520
# Fetching match 352 of 600 (match_id=8391273902)...
#  → Rows so far: 9530
# Fetching match 353 of 600 (match_id=8391273901)...
#  → Rows so far: 9540
# Fetching match 354 of 600 (match_id=8391273819)...
#  → Rows so far: 9550
# Fetching match 355 of 600 (match_id=8391273817)...
#  → Rows so far: 9560
# Fetching match 356 of 600 (match_id=8391273815)...
#  → Rows so far: 9570
# Fetching match 357 of 600 (match_id=8391273812)...
#  → Rows so far: 9580
# Fetching match 358 of 600 (match_id=8391273809)...
#  → Rows so far: 9590
# Fetching match 359 of 600 (match_id=8391273807)...
#  → Rows so far: 9600
# Fetching match 360 of 600 (match_id=8391273806)...
#  → Rows so far: 9610
# Fetching match 361 of 600 (match_id=8391273713)...
#  → Rows so far: 9620
# Fetching match 362 of 600 (match_id=8391273712)...
#  → Rows so far: 9630
# Fetching match 363 of 600 (match_id=8391273710)...
#  → Rows so far: 9640
# Fetching match 364 of 600 (match_id=8391273709)...
#  → Rows so far: 9650
# Fetching match 365 of 600 (match_id=8391273613)...
#  → Rows so far: 9660
# Fetching match 366 of 600 (match_id=8391273608)...
#  → Rows so far: 9670
# Fetching match 367 of 600 (match_id=8391273604)...
#  → Rows so far: 9680
# Fetching match 368 of 600 (match_id=8391273603)...
#  → Rows so far: 9690
# Fetching match 369 of 600 (match_id=8391273501)...
#  → Rows so far: 9700
# Fetching match 370 of 600 (match_id=8391273417)...
#  → Rows so far: 9710
# Fetching match 371 of 600 (match_id=8391273400)...
#  → Rows so far: 9720
# Fetching match 372 of 600 (match_id=8391273305)...
#  → Rows so far: 9730
# Fetching match 373 of 600 (match_id=8391273303)...
#  → Rows so far: 9740
# Fetching match 374 of 600 (match_id=8391273302)...
#  → Rows so far: 9750
# Fetching match 375 of 600 (match_id=8391273217)...
#  → Rows so far: 9760
# Fetching match 376 of 600 (match_id=8391273215)...
#  → Rows so far: 9770
# Fetching match 377 of 600 (match_id=8391273213)...
#  → Rows so far: 9780
# Fetching match 378 of 600 (match_id=8391273212)...
#  → Rows so far: 9790
# Fetching match 379 of 600 (match_id=8391273202)...
#  → Rows so far: 9800
# Fetching match 380 of 600 (match_id=8391273201)...
#  → Rows so far: 9810
# Fetching match 381 of 600 (match_id=8391273118)...
#  → Rows so far: 9820
# Fetching match 382 of 600 (match_id=8391273111)...
#  → Rows so far: 9830
# Fetching match 383 of 600 (match_id=8391273106)...
#  → Rows so far: 9840
# Fetching match 384 of 600 (match_id=8391273105)...
#  → Rows so far: 9850
# Fetching match 385 of 600 (match_id=8391273015)...
#  → Rows so far: 9860
# Fetching match 386 of 600 (match_id=8391273014)...
#  → Rows so far: 9870
# Fetching match 387 of 600 (match_id=8391273013)...
#  → Rows so far: 9880
# Fetching match 388 of 600 (match_id=8391273011)...
#  → Rows so far: 9890
# Fetching match 389 of 600 (match_id=8391273007)...
#  → Rows so far: 9900
# Fetching match 390 of 600 (match_id=8391273005)...
#  → Rows so far: 9910
# Fetching match 391 of 600 (match_id=8391273004)...
#  → Rows so far: 9920
# Fetching match 392 of 600 (match_id=8391272919)...
#  → Rows so far: 9930
# Fetching match 393 of 600 (match_id=8391272905)...
#  → Rows so far: 9940
# Fetching match 394 of 600 (match_id=8391272902)...
#  → Rows so far: 9950
# Fetching match 395 of 600 (match_id=8391272901)...
#  → Rows so far: 9960
# Fetching match 396 of 600 (match_id=8391272900)...
#  → Rows so far: 9970
# Fetching match 397 of 600 (match_id=8391272819)...
#  → Rows so far: 9980
# Fetching match 398 of 600 (match_id=8391272815)...
#  → Rows so far: 9990
# Fetching match 399 of 600 (match_id=8391272811)...
#  → Rows so far: 10000
# Fetching match 400 of 600 (match_id=8391272802)...
#  → Rows so far: 10010
# Fetching match 401 of 600 (match_id=8391272801)...
#  → Rows so far: 10020
# Fetching match 402 of 600 (match_id=8391272800)...
#  → Rows so far: 10030
# Fetching match 403 of 600 (match_id=8391272719)...
#  → Rows so far: 10040
# Fetching match 404 of 600 (match_id=8391272717)...
#  → Rows so far: 10050
# Fetching match 405 of 600 (match_id=8391272716)...
#  → Rows so far: 10060
# Fetching match 406 of 600 (match_id=8391272715)...
#  → Rows so far: 10070
# Fetching match 407 of 600 (match_id=8391272712)...
#  → Rows so far: 10080
# Fetching match 408 of 600 (match_id=8391272700)...
#  → Rows so far: 10090
# Fetching match 409 of 600 (match_id=8391272615)...
#  → Rows so far: 10100
# Fetching match 410 of 600 (match_id=8391272610)...
#  → Rows so far: 10110
# Fetching match 411 of 600 (match_id=8391272601)...
#  → Rows so far: 10120
# Fetching match 412 of 600 (match_id=8391272600)...
#  → Rows so far: 10130
# Fetching match 413 of 600 (match_id=8391272519)...
#  → Rows so far: 10140
# Fetching match 414 of 600 (match_id=8391272501)...
#  → Rows so far: 10150
# Fetching match 415 of 600 (match_id=8391272500)...
#  → Rows so far: 10160
# Fetching match 416 of 600 (match_id=8391272407)...
#  → Rows so far: 10170
# Fetching match 417 of 600 (match_id=8391272406)...
#  → Rows so far: 10180
# Fetching match 418 of 600 (match_id=8391272403)...
#  → Rows so far: 10190
# Fetching match 419 of 600 (match_id=8391272402)...
#  → Rows so far: 10200
# Fetching match 420 of 600 (match_id=8391272307)...
#  → Rows so far: 10210
# Fetching match 421 of 600 (match_id=8391272305)...
#  → Rows so far: 10220
# Fetching match 422 of 600 (match_id=8391272302)...
#  → Rows so far: 10230
# Fetching match 423 of 600 (match_id=8391272209)...
#  → Rows so far: 10240
# Fetching match 424 of 600 (match_id=8391272208)...
#  → Rows so far: 10250
# Fetching match 425 of 600 (match_id=8391272202)...
#  → Rows so far: 10260
# Fetching match 426 of 600 (match_id=8391272118)...
#  → Rows so far: 10270
# Fetching match 427 of 600 (match_id=8391272109)...
#  → Rows so far: 10280
# Fetching match 428 of 600 (match_id=8391272108)...
#  → Rows so far: 10290
# Fetching match 429 of 600 (match_id=8391272102)...
#  → Rows so far: 10300
# Fetching match 430 of 600 (match_id=8391272101)...
#  → Rows so far: 10310
# Fetching match 431 of 600 (match_id=8391272019)...
#  → Rows so far: 10320
# Fetching match 432 of 600 (match_id=8391272017)...
#  → Rows so far: 10330
# Fetching match 433 of 600 (match_id=8391272013)...
#  → Rows so far: 10340
# Fetching match 434 of 600 (match_id=8391272012)...
#  → Rows so far: 10350
# Fetching match 435 of 600 (match_id=8391272009)...
#  → Rows so far: 10360
# Fetching match 436 of 600 (match_id=8391272008)...
#  → Rows so far: 10370
# Fetching match 437 of 600 (match_id=8391271917)...
#  → Rows so far: 10380
# Fetching match 438 of 600 (match_id=8391271916)...
#  → Rows so far: 10390
# Fetching match 439 of 600 (match_id=8391271912)...
#  → Rows so far: 10400
# Fetching match 440 of 600 (match_id=8391271909)...
#  → Rows so far: 10410
# Fetching match 441 of 600 (match_id=8391271900)...
#  → Rows so far: 10420
# Fetching match 442 of 600 (match_id=8391271811)...
#  → Rows so far: 10430
# Fetching match 443 of 600 (match_id=8391271810)...
#  → Rows so far: 10440
# Fetching match 444 of 600 (match_id=8391271808)...
#  → Rows so far: 10450
# Fetching match 445 of 600 (match_id=8391271807)...
#  → Rows so far: 10460
# Fetching match 446 of 600 (match_id=8391271804)...
#  → Rows so far: 10470
# Fetching match 447 of 600 (match_id=8391271803)...
#  → Rows so far: 10480
# Fetching match 448 of 600 (match_id=8391271719)...
#  → Rows so far: 10490
# Fetching match 449 of 600 (match_id=8391271718)...
#  → Rows so far: 10500
# Fetching match 450 of 600 (match_id=8391271717)...
#  → Rows so far: 10510
# Fetching match 451 of 600 (match_id=8391271618)...
#  → Rows so far: 10520
# Fetching match 452 of 600 (match_id=8391271608)...
#  → Rows so far: 10530
# Fetching match 453 of 600 (match_id=8391271605)...
#  → Rows so far: 10540
# Fetching match 454 of 600 (match_id=8391271604)...
#  → Rows so far: 10550
# Fetching match 455 of 600 (match_id=8391271603)...
#  → Rows so far: 10560
# Fetching match 456 of 600 (match_id=8391271514)...
#  → Rows so far: 10570
# Fetching match 457 of 600 (match_id=8391271507)...
#  → Rows so far: 10580
# Fetching match 458 of 600 (match_id=8391271506)...
#  → Rows so far: 10590
# Fetching match 459 of 600 (match_id=8391271501)...
#  → Rows so far: 10600
# Fetching match 460 of 600 (match_id=8391271500)...
#  → Rows so far: 10610
# Fetching match 461 of 600 (match_id=8391271418)...
#  → Rows so far: 10620
# Fetching match 462 of 600 (match_id=8391271417)...
#  → Rows so far: 10630
# Fetching match 463 of 600 (match_id=8391271411)...
#  → Rows so far: 10640
# Fetching match 464 of 600 (match_id=8391271409)...
#  → Rows so far: 10650
# Fetching match 465 of 600 (match_id=8391271408)...
#  → Rows so far: 10660
# Fetching match 466 of 600 (match_id=8391271406)...
#  → Rows so far: 10670
# Fetching match 467 of 600 (match_id=8391271404)...
#  → Rows so far: 10680
# Fetching match 468 of 600 (match_id=8391271309)...
#  → Rows so far: 10690
# Fetching match 469 of 600 (match_id=8391271307)...
#  → Rows so far: 10700
# Fetching match 470 of 600 (match_id=8391271305)...
#  → Rows so far: 10710
# Fetching match 471 of 600 (match_id=8391271302)...
#  → Rows so far: 10720
# Fetching match 472 of 600 (match_id=8391271212)...
#  → Rows so far: 10730
# Fetching match 473 of 600 (match_id=8391271210)...
#  → Rows so far: 10740
# Fetching match 474 of 600 (match_id=8391271208)...
#  → Rows so far: 10750
# Fetching match 475 of 600 (match_id=8391271205)...
#  → Rows so far: 10760
# Fetching match 476 of 600 (match_id=8391271111)...
#  → Rows so far: 10770
# Fetching match 477 of 600 (match_id=8391271110)...
#  → Rows so far: 10780
# Fetching match 478 of 600 (match_id=8391271108)...
#  → Rows so far: 10790
# Fetching match 479 of 600 (match_id=8391271107)...
#  → Rows so far: 10800
# Fetching match 480 of 600 (match_id=8391271106)...
#  → Rows so far: 10810
# Fetching match 481 of 600 (match_id=8391271105)...
#  → Rows so far: 10820
# Fetching match 482 of 600 (match_id=8391271102)...
#  → Rows so far: 10830
# Fetching match 483 of 600 (match_id=8391271100)...
#  → Rows so far: 10840
# Fetching match 484 of 600 (match_id=8391271017)...
#  → Rows so far: 10850
# Fetching match 485 of 600 (match_id=8391271014)...
#  → Rows so far: 10860
# Fetching match 486 of 600 (match_id=8391270918)...
#  → Rows so far: 10870
# Fetching match 487 of 600 (match_id=8391270917)...
#  → Rows so far: 10880
# Fetching match 488 of 600 (match_id=8391270915)...
#  → Rows so far: 10890
# Fetching match 489 of 600 (match_id=8391270906)...
#  → Rows so far: 10900
# Fetching match 490 of 600 (match_id=8391270819)...
#  → Rows so far: 10910
# Fetching match 491 of 600 (match_id=8391270815)...
#  → Rows so far: 10920
# Fetching match 492 of 600 (match_id=8391270814)...
#  → Rows so far: 10930
# Fetching match 493 of 600 (match_id=8391270813)...
#  → Rows so far: 10940
# Fetching match 494 of 600 (match_id=8391270810)...
#  → Rows so far: 10950
# Fetching match 495 of 600 (match_id=8391270719)...
#  → Rows so far: 10960
# Fetching match 496 of 600 (match_id=8391270718)...
#  → Rows so far: 10970
# Fetching match 497 of 600 (match_id=8391270717)...
#  → Rows so far: 10980
# Fetching match 498 of 600 (match_id=8391270709)...
#  → Rows so far: 10990
# Fetching match 499 of 600 (match_id=8391270708)...
#  → Rows so far: 11000
# Fetching match 500 of 600 (match_id=8391270705)...
#  → Rows so far: 11010
# Fetching match 501 of 600 (match_id=8391270615)...
#  → Rows so far: 11020
# Fetching match 502 of 600 (match_id=8391270612)...
#  → Rows so far: 11030
# Fetching match 503 of 600 (match_id=8391270610)...
#  → Rows so far: 11040
# Fetching match 504 of 600 (match_id=8391270516)...
#  → Rows so far: 11050
# Fetching match 505 of 600 (match_id=8391270500)...
#  → Rows so far: 11060
# Fetching match 506 of 600 (match_id=8391270417)...
#  → Rows so far: 11070
# Fetching match 507 of 600 (match_id=8391270406)...
#  → Rows so far: 11080
# Fetching match 508 of 600 (match_id=8391270403)...
#  → Rows so far: 11090
# Fetching match 509 of 600 (match_id=8391270314)...
#  → Rows so far: 11100
# Fetching match 510 of 600 (match_id=8391270313)...
#  → Rows so far: 11110
# Fetching match 511 of 600 (match_id=8391270312)...
#  → Rows so far: 11120
# Fetching match 512 of 600 (match_id=8391270309)...
#  → Rows so far: 11130
# Fetching match 513 of 600 (match_id=8391270307)...
#  → Rows so far: 11140
# Fetching match 514 of 600 (match_id=8391270207)...
#  → Rows so far: 11150
# Fetching match 515 of 600 (match_id=8391270204)...
#  → Rows so far: 11160
# Fetching match 516 of 600 (match_id=8391270203)...
#  → Rows so far: 11170
# Fetching match 517 of 600 (match_id=8391270109)...
#  → Rows so far: 11180
# Fetching match 518 of 600 (match_id=8391270106)...
#  → Rows so far: 11190
# Fetching match 519 of 600 (match_id=8391270105)...
#  → Rows so far: 11200
# Fetching match 520 of 600 (match_id=8391270104)...
#  → Rows so far: 11210
# Fetching match 521 of 600 (match_id=8391270103)...
#  → Rows so far: 11220
# Fetching match 522 of 600 (match_id=8391270012)...
#  → Rows so far: 11230
# Fetching match 523 of 600 (match_id=8391270007)...
#  → Rows so far: 11240
# Fetching match 524 of 600 (match_id=8391270006)...
#  → Rows so far: 11250
# Fetching match 525 of 600 (match_id=8391269919)...
#  → Rows so far: 11260
# Fetching match 526 of 600 (match_id=8391269917)...
#  → Rows so far: 11270
# Fetching match 527 of 600 (match_id=8391269915)...
#  → Rows so far: 11280
# Fetching match 528 of 600 (match_id=8391269906)...
#  → Rows so far: 11290
# Fetching match 529 of 600 (match_id=8391269905)...
#  → Rows so far: 11300
# Fetching match 530 of 600 (match_id=8391269902)...
#  → Rows so far: 11310
# Fetching match 531 of 600 (match_id=8391269901)...
#  → Rows so far: 11320
# Fetching match 532 of 600 (match_id=8391269816)...
#  → Rows so far: 11330
# Fetching match 533 of 600 (match_id=8391269814)...
#  → Rows so far: 11340
# Fetching match 534 of 600 (match_id=8391269812)...
#  → Rows so far: 11350
# Fetching match 535 of 600 (match_id=8391269811)...
#  → Rows so far: 11360
# Fetching match 536 of 600 (match_id=8391269810)...
#  → Rows so far: 11370
# Fetching match 537 of 600 (match_id=8391269808)...
#  → Rows so far: 11380
# Fetching match 538 of 600 (match_id=8391269719)...
#  → Rows so far: 11390
# Fetching match 539 of 600 (match_id=8391269718)...
#  → Rows so far: 11400
# Fetching match 540 of 600 (match_id=8391269710)...
#  → Rows so far: 11410
# Fetching match 541 of 600 (match_id=8391269708)...
#  → Rows so far: 11420
# Fetching match 542 of 600 (match_id=8391269707)...
#  → Rows so far: 11430
# Fetching match 543 of 600 (match_id=8391269705)...
#  → Rows so far: 11440
# Fetching match 544 of 600 (match_id=8391269619)...
#  → Rows so far: 11450
# Fetching match 545 of 600 (match_id=8391269618)...
#  → Rows so far: 11460
# Fetching match 546 of 600 (match_id=8391269600)...
#  → Rows so far: 11470
# Fetching match 547 of 600 (match_id=8391269519)...
#  → Rows so far: 11480
# Fetching match 548 of 600 (match_id=8391269513)...
#  → Rows so far: 11490
# Fetching match 549 of 600 (match_id=8391269502)...
#  → Rows so far: 11500
# Fetching match 550 of 600 (match_id=8391269501)...
#  → Rows so far: 11510
# Fetching match 551 of 600 (match_id=8391269407)...
#  → Rows so far: 11520
# Fetching match 552 of 600 (match_id=8391269404)...
#  → Rows so far: 11530
# Fetching match 553 of 600 (match_id=8391269403)...
#  → Rows so far: 11540
# Fetching match 554 of 600 (match_id=8391269319)...
#  → Rows so far: 11550
# Fetching match 555 of 600 (match_id=8391269307)...
#  → Rows so far: 11560
# Fetching match 556 of 600 (match_id=8391269306)...
#  → Rows so far: 11570
# Fetching match 557 of 600 (match_id=8391269305)...
#  → Rows so far: 11580
# Fetching match 558 of 600 (match_id=8391269303)...
#  → Rows so far: 11590
# Fetching match 559 of 600 (match_id=8391269301)...
#  → Rows so far: 11600
# Fetching match 560 of 600 (match_id=8391269300)...
#  → Rows so far: 11610
# Fetching match 561 of 600 (match_id=8391269219)...
#  → Rows so far: 11620
# Fetching match 562 of 600 (match_id=8391269201)...
#  → Rows so far: 11630
# Fetching match 563 of 600 (match_id=8391269118)...
#  → Rows so far: 11640
# Fetching match 564 of 600 (match_id=8391269117)...
#  → Rows so far: 11650
# Fetching match 565 of 600 (match_id=8391269115)...
#  → Rows so far: 11660
# Fetching match 566 of 600 (match_id=8391269106)...
#  → Rows so far: 11670
# Fetching match 567 of 600 (match_id=8391269105)...
#  → Rows so far: 11680
# Fetching match 568 of 600 (match_id=8391269103)...
#  → Rows so far: 11690
# Fetching match 569 of 600 (match_id=8391269102)...
#  → Rows so far: 11700
# Fetching match 570 of 600 (match_id=8391269014)...
#  → Rows so far: 11710
# Fetching match 571 of 600 (match_id=8391269012)...
#  → Rows so far: 11720
# Fetching match 572 of 600 (match_id=8391269011)...
#  → Rows so far: 11730
# Fetching match 573 of 600 (match_id=8391269010)...
#  → Rows so far: 11740
# Fetching match 574 of 600 (match_id=8391269009)...
#  → Rows so far: 11750
# Fetching match 575 of 600 (match_id=8391269005)...
#  → Rows so far: 11760
# Fetching match 576 of 600 (match_id=8391268917)...
#  → Rows so far: 11770
# Fetching match 577 of 600 (match_id=8391268916)...
#  → Rows so far: 11780
# Fetching match 578 of 600 (match_id=8391268915)...
#  → Rows so far: 11790
# Fetching match 579 of 600 (match_id=8391268819)...
#  → Rows so far: 11800
# Fetching match 580 of 600 (match_id=8391268817)...
#  → Rows so far: 11810
# Fetching match 581 of 600 (match_id=8391268804)...
#  → Rows so far: 11820
# Fetching match 582 of 600 (match_id=8391268800)...
#  → Rows so far: 11830
# Fetching match 583 of 600 (match_id=8391268715)...
#  → Rows so far: 11840
# Fetching match 584 of 600 (match_id=8391268713)...
#  → Rows so far: 11850
# Fetching match 585 of 600 (match_id=8391268712)...
#  → Rows so far: 11860
# Fetching match 586 of 600 (match_id=8391268711)...
#  → Rows so far: 11870
# Fetching match 587 of 600 (match_id=8391268710)...
#  → Rows so far: 11880
# Fetching match 588 of 600 (match_id=8391268618)...
#  → Rows so far: 11890
# Fetching match 589 of 600 (match_id=8391268617)...
#  → Rows so far: 11900
# Fetching match 590 of 600 (match_id=8391268614)...
#  → Rows so far: 11910
# Fetching match 591 of 600 (match_id=8391268612)...
#  → Rows so far: 11920
# Fetching match 592 of 600 (match_id=8391268603)...
#  → Rows so far: 11930
# Fetching match 593 of 600 (match_id=8391268601)...
#  → Rows so far: 11940
# Fetching match 594 of 600 (match_id=8391268519)...
#  → Rows so far: 11950
# Fetching match 595 of 600 (match_id=8391268517)...
#  → Rows so far: 11960
# Fetching match 596 of 600 (match_id=8391268516)...
#  → Rows so far: 11970
# Fetching match 597 of 600 (match_id=8391268515)...
#  → Rows so far: 11980
# Fetching match 598 of 600 (match_id=8391268514)...
#  → Rows so far: 11990
# Fetching match 599 of 600 (match_id=8391268513)...
#  → Rows so far: 12000
# Fetching match 600 of 600 (match_id=8391268511)...
#  → Rows so far: 12010
#
# Saved 12010 rows to C:\Users\Ellen\Desktop\OpenDota Data\match_details_500matches.csv
# Matches processed: 1201 of 1100

# %% [markdown]
# **Data sanity check**
#
# Summary of row counts per column, unique players, etc.

# %%
import pandas as pd

# Loading dataset
file_path = r"C:\Users\Ellen\Desktop\OpenDota Data\match_details_500matches.csv"
df = pd.read_csv(file_path)

# Summary
print("=== Basic Info ===")
print(f"Rows: {len(df)}")
print(f"Unique matches: {df['match_id'].nunique()}")
print(f"Unique players: {df['account_id'].nunique()}")

print("\n=== Basic Stats ===")
print(df[['kills','deaths','assists','gold_per_min','xp_per_min']].describe())

print("\n=== Hero Frequency ===")
print(df['hero_id'].value_counts().head(10))
# Out:
# === Basic Info ===
# Rows: 12010
# Unique matches: 1201
# Unique players: 5706
#
# === Basic Stats ===
#               kills        deaths       assists  gold_per_min    xp_per_min
# count  12010.000000  12010.000000  12010.000000  12010.000000  12010.000000
# mean       7.162032      7.355121     13.385012    465.458118    626.817735
# std        5.296589      3.996651      7.740610    149.830950    227.653245
# min        0.000000      0.000000      0.000000    103.000000      1.000000
# 25%        3.000000      4.000000      7.000000    356.000000    465.000000
# 50%        6.000000      7.000000     12.000000    446.000000    602.000000
# 75%       10.000000     10.000000     18.000000    568.000000    765.000000
# max       37.000000     26.000000     53.000000   1169.000000   1767.000000
#
# === Hero Frequency ===
# hero_id
# 14     347
# 2      299
# 53     278
# 26     271
# 27     256
# 39     251
# 11     249
# 30     240
# 75     232
# 104    210
# Name: count, dtype: int64

# %% [markdown]
# **3. Pulling Hero Data**

# %%
# OpenDota heroes endpoint
HEROES_URL = "https://api.opendota.com/api/heroes"
response = requests.get(HEROES_URL)

if response.status_code == 200:
    heroes_data = response.json()
    heroes_df = pd.DataFrame(heroes_data)
    print("First 5 heroes:\n", heroes_df.head())

    # Save heroes data
    heroes_path = r"C:\Users\Ellen\Desktop\OpenDota Data\heroes.csv"
    heroes_df.to_csv(heroes_path, index=False)
    print(f"Heroes data saved to {heroes_path}")
else:
    print(f"Failed to fetch heroes: {response.status_code}")
# Out:
# First 5 heroes:
#     id                          name  localized_name primary_attr attack_type  \
# 0   1        npc_dota_hero_antimage       Anti-Mage          agi       Melee
# 1   2             npc_dota_hero_axe             Axe          str       Melee
# 2   3            npc_dota_hero_bane            Bane          all      Ranged
# 3   4     npc_dota_hero_bloodseeker     Bloodseeker          agi       Melee
# 4   5  npc_dota_hero_crystal_maiden  Crystal Maiden          int      Ranged
#
#                                    roles  legs
# 0                 [Carry, Escape, Nuker]     2
# 1  [Initiator, Durable, Disabler, Carry]     2
# 2    [Support, Disabler, Nuker, Durable]     4
# 3    [Carry, Disabler, Nuker, Initiator]     2
# 4             [Support, Disabler, Nuker]     2
# Heroes data saved to C:\Users\Ellen\Desktop\OpenDota Data\heroes.csv

# %% [markdown]
# **Pulling live data (match-level)**

# %%
# OpenDota live matches endpoint
LIVE_URL = "https://api.opendota.com/api/live"

def fetch_live_matches():
    response = requests.get(LIVE_URL)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch live matches. Status code: {response.status_code}")
        return None

# Fetch live matches once
live_data = fetch_live_matches()

if live_data:
    # Flatten relevant data for each match
    rows = []
    for match in live_data:
        rows.append({
            "match_id": match.get("match_id"),
            "activate_time": match.get("activate_time"),
            "deactivate_time": match.get("deactivate_time"),
            "league_id": match.get("league_id"),
            "series_id": match.get("series_id"),
            "average_mmr": match.get("average_mmr"),
            "game_mode": match.get("game_mode"),
            "radiant_lead": match.get("radiant_lead"),
            "building_state": match.get("building_state"),
            "radiant_score": match.get("radiant_score"),
            "dire_score": match.get("dire_score"),
            "radiant_team_name": match.get("team_name_radiant"),
            "dire_team_name": match.get("team_name_dire"),
            "radiant_team_id": match.get("team_id_radiant"),
            "dire_team_id": match.get("team_id_dire"),
        })

    df_live = pd.DataFrame(rows)

    # Save to CSV
    output_path = r"C:\Users\Ellen\Desktop\OpenDota Data\live_matches.csv"
    df_live.to_csv(output_path, index=False)
    print(f"Saved {len(df_live)} live matches to {output_path}")
else:
    print("No live matches fetched.")
# Out:
# Saved 100 live matches to C:\Users\Ellen\Desktop\OpenDota Data\live_matches.csv

# %% [markdown]
# **Pulling live data (player-level)**

# %%
# OpenDota live matches endpoint
LIVE_URL = "https://api.opendota.com/api/live"

def fetch_live_matches():
    response = requests.get(LIVE_URL)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch live matches. Status code: {response.status_code}")
        return None

# Fetch live match data
live_data = fetch_live_matches()

if live_data:
    rows = []
    for match in live_data:
        match_id = match.get("match_id")
        activate_time = match.get("activate_time")
        deactivate_time = match.get("deactivate_time")
        league_id = match.get("league_id")
        series_id = match.get("series_id")
        average_mmr = match.get("average_mmr")
        game_mode = match.get("game_mode")
        radiant_lead = match.get("radiant_lead")
        building_state = match.get("building_state")
        radiant_score = match.get("radiant_score")
        dire_score = match.get("dire_score")
        radiant_team_name = match.get("team_name_radiant")
        dire_team_name = match.get("team_name_dire")
        radiant_team_id = match.get("team_id_radiant")
        dire_team_id = match.get("team_id_dire")

        # Loop through players in each match
        for player in match.get("players", []):
            rows.append({
                "match_id": match_id,
                "activate_time": activate_time,
                "deactivate_time": deactivate_time,
                "league_id": league_id,
                "series_id": series_id,
                "average_mmr": average_mmr,
                "game_mode": game_mode,
                "radiant_lead": radiant_lead,
                "building_state": building_state,
                "radiant_score": radiant_score,
                "dire_score": dire_score,
                "radiant_team_name": radiant_team_name,
                "dire_team_name": dire_team_name,
                "radiant_team_id": radiant_team_id,
                "dire_team_id": dire_team_id,
                "player_account_id": player.get("account_id"),
                "player_name": player.get("name"),
                "hero_id": player.get("hero_id"),
                "team": player.get("team")  # 0 = Radiant, 1 = Dire
            })

    df_live_players = pd.DataFrame(rows)

    # Save to CSV
    output_path = r"C:\Users\Ellen\Desktop\OpenDota Data\live_matches_players.csv"
    df_live_players.to_csv(output_path, index=False)
    print(f"Saved {len(df_live_players)} player rows to {output_path}")
else:
    print("No live matches fetched.")
# Out:
# Saved 975 player rows to C:\Users\Ellen\Desktop\OpenDota Data\live_matches_players.csv

# %% [markdown]
# **Sanity Check**

# %%
# Load player-level live match data
file_path = r"C:\Users\Ellen\Desktop\OpenDota Data\live_matches_players.csv"
df = pd.read_csv(file_path)

# Basic counts
total_rows = len(df)
unique_matches = df['match_id'].nunique()
unique_players = df['player_account_id'].nunique()

print(f"Rows: {total_rows}")
print(f"Unique matches: {unique_matches}")
print(f"Unique players (public IDs only): {unique_players}")

# Hero frequency
hero_counts = df['hero_id'].value_counts().head(10)
print("\n=== Top 10 Heroes ===")
print(hero_counts)

# Team breakdown
team_counts = df['team'].value_counts()  # 0 = Radiant, 1 = Dire
print("\n=== Team Counts ===")
print(team_counts)
# Out:
# Rows: 975
# Unique matches: 98
# Unique players (public IDs only): 735
#
# === Top 10 Heroes ===
# hero_id
# 11     35
# 53     30
# 135    29
# 39     27
# 14     27
# 2      27
# 27     25
# 86     23
# 26     21
# 70     19
# Name: count, dtype: int64
#
# === Team Counts ===
# team
# 1    489
# 0    486
# Name: count, dtype: int64

# %% [markdown]
# **4. Pulling Constants Data (items)**

# %%
# OpenDota constants items endpoint
ITEMS_URL = "https://api.opendota.com/api/constants/items"

def fetch_items():
    response = requests.get(ITEMS_URL)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch items. Status code: {response.status_code}")
        return None

items_data = fetch_items()

if items_data:
    rows = []
    for key, item in items_data.items():
        rows.append({
            "item_id": item.get("id"),
            "name": key,
            "localized_name": item.get("dname"),
            "cost": item.get("cost"),
            "notes": item.get("notes"),
            "qual": item.get("qual"),
            "created": item.get("created"),
            "charges": item.get("charges")
        })

    df_items = pd.DataFrame(rows)
    output_path = r"C:\Users\Ellen\Desktop\OpenDota Data\items.csv"
    df_items.to_csv(output_path, index=False)
    print(f"Items data saved to {output_path}")
else:
    print("No items data fetched.")
# Out:
# Items data saved to C:\Users\Ellen\Desktop\OpenDota Data\items.csv

# %% [markdown]
# **Pulling Constants (game modes)**

# %%
# OpenDota constants game modes endpoint
GAMEMODES_URL = "https://api.opendota.com/api/constants/game_mode"

def fetch_game_modes():
    response = requests.get(GAMEMODES_URL)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch game modes. Status code: {response.status_code}")
        return None

game_modes_data = fetch_game_modes()

if game_modes_data:
    rows = []
    for key, gm in game_modes_data.items():
        rows.append({
            "id": gm.get("id"),
            "name": gm.get("name"),
            "balanced": gm.get("balanced")
        })
    df_game_modes = pd.DataFrame(rows)
    output_path = r"C:\Users\Ellen\Desktop\OpenDota Data\game_modes.csv"
    df_game_modes.to_csv(output_path, index=False)
    print(f"Game modes data saved to {output_path}")
else:
    print("No game modes data fetched.")
# Out:
# Game modes data saved to C:\Users\Ellen\Desktop\OpenDota Data\game_modes.csv

# %% [markdown]
# **Pulling Constants Data (lobby and region)**

# %%
# OpenDota constants endpoints
LOBBY_TYPES_URL = "https://api.opendota.com/api/constants/lobby_type"
REGIONS_URL = "https://api.opendota.com/api/constants/region"

def fetch_constants(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch constants from {url}. Status code: {response.status_code}")
        return None

# --- Fetch Lobby Types ---
lobby_types = fetch_constants(LOBBY_TYPES_URL)
if lobby_types:
    rows = []
    for key, val in lobby_types.items():
        rows.append({
            "id": val.get("id"),
            "name": val.get("name"),
            "description": val.get("description")
        })
    df_lobby_types = pd.DataFrame(rows)
    output_lobby = r"C:\Users\Ellen\Desktop\OpenDota Data\lobby_types.csv"
    df_lobby_types.to_csv(output_lobby, index=False)
    print(f"Lobby types saved to {output_lobby}")
else:
    print("No lobby types data fetched.")

# --- Fetch Regions ---
regions = fetch_constants(REGIONS_URL)
if regions:
    rows = []
    for key, val in regions.items():
        rows.append({
            "region_id": key,
            "region_name": val
        })
    df_regions = pd.DataFrame(rows)
    output_regions = r"C:\Users\Ellen\Desktop\OpenDota Data\regions.csv"
    df_regions.to_csv(output_regions, index=False)
    print(f"Regions saved to {output_regions}")
else:
    print("No regions data fetched.")
# Out:
# Lobby types saved to C:\Users\Ellen\Desktop\OpenDota Data\lobby_types.csv
# Regions saved to C:\Users\Ellen\Desktop\OpenDota Data\regions.csv

# %% [markdown]
# **6. Pulling Ranking data to (region_id check)**

# %%
import requests
import pandas as pd

HERO_ID = 11  # top hero in your live matches
RANKINGS_URL = f"https://api.opendota.com/api/rankings?hero_id={HERO_ID}"

response = requests.get(RANKINGS_URL)
if response.status_code == 200:
    rankings = response.json().get("rankings", [])
    df_rankings = pd.DataFrame(rankings)
    output_path = r"C:\Users\Ellen\Desktop\OpenDota Data\rankings_hero11.csv"
    df_rankings.to_csv(output_path, index=False)
    print(f"Rankings data saved to {output_path}")
    print(df_rankings.head())
else:
    print(f"Failed to fetch rankings. Status code: {response.status_code}")
# Out:
# Rankings data saved to C:\Users\Ellen\Desktop\OpenDota Data\rankings_hero11.csv
#    account_id        score  personaname  name  \
# 0   356090976  8880.315555      гадость  None
# 1    33388894  8638.873910          zzz  None
# 2   213952287  8567.868860    不上手机令牌封游戏  None
# 3   387395868  8555.126059  grafvishnya  None
# 4   240842238  8539.649902         Fino  None
#
#                                               avatar  \
# 0  https://avatars.steamstatic.com/bb0bd4ceaa58d8...
# 1  https://avatars.steamstatic.com/c9fdc165d2e684...
# 2  https://avatars.steamstatic.com/44b2254cdd684d...
# 3  https://avatars.steamstatic.com/6953b663f4d625...
# 4  https://avatars.steamstatic.com/defb3862db8a81...
#
#                  last_login  rank_tier
# 0  2025-05-31T23:26:30.247Z         80
# 1  2025-03-25T16:19:33.490Z         80
# 2                      None         80
# 3  2022-10-26T08:18:19.357Z         80
# 4                      None         80

# %% [markdown]
# **7. Pulling Distribution data (region_id check)**

# %%
DISTRIBUTION_URL = "https://api.opendota.com/api/distributions"

response = requests.get(DISTRIBUTION_URL)
if response.status_code == 200:
    data = response.json()
    # Check what keys are present
    print("Keys returned:", data.keys())

    # Save full JSON to file for inspection
    output_path = r"C:\Users\Ellen\Desktop\OpenDota Data\distribution_full.json"
    import json
    with open(output_path, "w") as f:
        json.dump(data, f, indent=4)
    print(f"Distribution data saved to {output_path}")
else:
    print(f"Failed to fetch distribution data. Status code: {response.status_code}")
# Out:
# Keys returned: dict_keys(['ranks'])
# Distribution data saved to C:\Users\Ellen\Desktop\OpenDota Data\distribution_full.json

# %% [markdown]
# **Converting distribution from json to csv**

# %%
# --- Fetch distribution data ---
DISTRIBUTION_URL = "https://api.opendota.com/api/distributions"
response = requests.get(DISTRIBUTION_URL)

if response.status_code == 200:
    data = response.json()

    # Extract the ranks rows
    ranks_data = data.get("ranks", {}).get("rows", [])
    df = pd.DataFrame(ranks_data)

    # Save to CSV
    output_path = r"C:\Users\Ellen\Desktop\OpenDota Data\rank_distributions.csv"
    df.to_csv(output_path, index=False)
    print(f"Rank distributions saved to {output_path}")
    print(df.head())
else:
    print(f"Failed to fetch distribution data. Status code: {response.status_code}")
# Out:
# Rank distributions saved to C:\Users\Ellen\Desktop\OpenDota Data\rank_distributions.csv
#    bin  bin_name   count  cumulative_sum
# 0   11        11    4460            4460
# 1   12        12   79936           84396
# 2   13        13   90740          175136
# 3   14        14  115380          290516
# 4   15        15  133126          423642
